# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('../data/train.txt', sep='\t', header=None)
val = pd.read_csv('../data/val.txt', sep='\t', header=None)
test = pd.read_csv('../data/test.txt', sep='\t', header=None)

# %% [markdown]
# # Train data

# %%
train.shape
# Out:
# (1181, 3)

# %%
print('unique cell line: ' + str(len(set(train[0]))))
print('unique SMILES: ' + str(len(set(train[1]))))
# Out:
# unique cell line: 55
# unique SMILES: 37

# %% [markdown]
# # Validation data

# %%
val.shape
# Out:
# (393, 3)

# %%
print('unique cell line: ' + str(len(set(val[0]))))
print('unique SMILES: ' + str(len(set(val[1]))))
# Out:
# unique cell line: 55
# unique SMILES: 37

# %%
val[0].value_counts()
# Out:
# MDAMB231_BREAST                                12
# RXF393_KIDNEY                                  11
# HCT15_LARGE_INTESTINE                          11
# CAKI1_KIDNEY                                   11
# SKMEL5_SKIN                                    11
# T47D_BREAST                                    10
# IGROV1_OVARY                                   10
# SW620_LARGE_INTESTINE                          10
# OVCAR5_OVARY                                   10
# NCIH226_LUNG                                    9
# 786O_KIDNEY                                     9
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         9
# SKMEL28_SKIN                                    9
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         9
# TK10_KIDNEY                                     9
# SKMEL2_SKIN                                     8
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      8
# HOP92_LUNG                                      8
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        8
# SKOV3_OVARY                                     8
# UACC257_SKIN                                    8
# HOP62_LUNG                                      7
# SF539_CENTRAL_NERVOUS_SYSTEM                    7
# HT29_LARGE_INTESTINE                            7
# BT549_BREAST                                    7
# NCIH522_LUNG                                    7
# A549_LUNG                                       7
# M14_SKIN                                        7
# COLO205_LARGE_INTESTINE                         7
# MDAMB435S_SKIN                                  7
# SNB75_CENTRAL_NERVOUS_SYSTEM                    7
# SN12C_KIDNEY                                    7
# EKVX_LUNG                                       7
# ACHN_KIDNEY                                     7
# U251MG_CENTRAL_NERVOUS_SYSTEM                   7
# NCIH23_LUNG                                     6
# HCT116_LARGE_INTESTINE                          6
# SF295_CENTRAL_NERVOUS_SYSTEM                    6
# MALME3M_SKIN                                    6
# NCIH460_LUNG                                    6
# PC3_PROSTATE                                    6
# MCF7_BREAST                                     6
# HS578T_BREAST                                   6
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        6
# LOXIMVI_SKIN                                    6
# DU145_PROSTATE                                  5
# UACC62_SKIN                                     5
# SF268_CENTRAL_NERVOUS_SYSTEM                    4
# A498_KIDNEY                                     4
# KM12_LARGE_INTESTINE                            4
# OVCAR8_OVARY                                    4
# HCC2998_LARGE_INTESTINE                         3
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     3
# OVCAR4_OVARY                                    3
# NCIH322_LUNG                                    2
# Name: 0, dtype: int64

# %% [markdown]
# # Test data

# %%
test = pd.read_csv(
    '../data/test.txt',
    sep='\t',
    header=None
)

# %%
test.shape
# Out:
# (393, 3)

# %%
print('unique cell line: ' + str(len(set(test[0]))))
print('unique SMILES: ' + str(len(set(test[1]))))
# Out:
# unique cell line: 55
# unique SMILES: 37

# %%
test[0].value_counts()
# Out:
# M14_SKIN                                       14
# DU145_PROSTATE                                 14
# HCC2998_LARGE_INTESTINE                        13
# SKMEL2_SKIN                                    11
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       11
# SKMEL28_SKIN                                   10
# HS578T_BREAST                                  10
# LOXIMVI_SKIN                                   10
# MCF7_BREAST                                    10
# OVCAR4_OVARY                                   10
# CAKI1_KIDNEY                                   10
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        10
# NCIH23_LUNG                                    10
# NCIH322_LUNG                                    9
# HCT15_LARGE_INTESTINE                           9
# MALME3M_SKIN                                    9
# IGROV1_OVARY                                    8
# UACC62_SKIN                                     8
# EKVX_LUNG                                       8
# NCIH226_LUNG                                    8
# HOP62_LUNG                                      7
# SF295_CENTRAL_NERVOUS_SYSTEM                    7
# RXF393_KIDNEY                                   7
# BT549_BREAST                                    7
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     7
# NCIH460_LUNG                                    7
# SF539_CENTRAL_NERVOUS_SYSTEM                    7
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        7
# SN12C_KIDNEY                                    7
# OVCAR8_OVARY                                    6
# SKMEL5_SKIN                                     6
# HOP92_LUNG                                      6
# ACHN_KIDNEY                                     6
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         6
# A549_LUNG                                       6
# A498_KIDNEY                                     6
# U251MG_CENTRAL_NERVOUS_SYSTEM                   6
# TK10_KIDNEY                                     6
# PC3_PROSTATE                                    6
# NCIH522_LUNG                                    6
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      5
# HT29_LARGE_INTESTINE                            5
# MDAMB231_BREAST                                 5
# SNB75_CENTRAL_NERVOUS_SYSTEM                    5
# COLO205_LARGE_INTESTINE                         5
# 786O_KIDNEY                                     5
# MDAMB435S_SKIN                                  5
# SW620_LARGE_INTESTINE                           5
# SF268_CENTRAL_NERVOUS_SYSTEM                    4
# KM12_LARGE_INTESTINE                            4
# HCT116_LARGE_INTESTINE                          3
# UACC257_SKIN                                    3
# T47D_BREAST                                     3
# SKOV3_OVARY                                     3
# OVCAR5_OVARY                                    2
# Name: 0, dtype: int64

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train[0].value_counts()), 
        pd.DataFrame(val[0].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test[0].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
df
# Out:
#                                              train  val  test
# SF268_CENTRAL_NERVOUS_SYSTEM                    29    4     4
# KM12_LARGE_INTESTINE                            28    4     4
# HCT116_LARGE_INTESTINE                          28    6     3
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     27    3     7
# OVCAR8_OVARY                                    27    4     6
# A498_KIDNEY                                     25    4     6
# NCIH322_LUNG                                    25    2     9
# SKOV3_OVARY                                     24    8     3
# SNB75_CENTRAL_NERVOUS_SYSTEM                    24    7     5
# SF295_CENTRAL_NERVOUS_SYSTEM                    24    6     7
# A549_LUNG                                       24    7     6
# NCIH522_LUNG                                    24    7     6
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      24    8     5
# NCIH460_LUNG                                    24    6     7
# ACHN_KIDNEY                                     24    7     6
# U251MG_CENTRAL_NERVOUS_SYSTEM                   24    7     6
# OVCAR5_OVARY                                    23   10     2
# SF539_CENTRAL_NERVOUS_SYSTEM                    23    7     7
# UACC62_SKIN                                     23    5     8
# UACC257_SKIN                                    23    8     3
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        23    6     7
# COLO205_LARGE_INTESTINE                         23    7     5
# OVCAR4_OVARY                                    23    3    10
# SN12C_KIDNEY                                    23    7     7
# MDAMB435S_SKIN                                  23    7     5
# HT29_LARGE_INTESTINE                            23    7     5
# PC3_PROSTATE                                    23    6     6
# HOP62_LUNG                                      22    7     7
# 786O_KIDNEY                                     22    9     5
# TK10_KIDNEY                                     21    9     6
# HOP92_LUNG                                      21    8     6
# SW620_LARGE_INTESTINE                           21   10     5
# LOXIMVI_SKIN                                    21    6    10
# NCIH23_LUNG                                     21    6    10
# HS578T_BREAST                                   20    6    10
# NCIH226_LUNG                                    20    9     8
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         20    9     6
# HCC2998_LARGE_INTESTINE                         20    3    13
# SKMEL5_SKIN                                     19   11     6
# IGROV1_OVARY                                    19   10     8
# BT549_BREAST                                    19    7     7
# MDAMB231_BREAST                                 19   12     5
# EKVX_LUNG                                       19    7     8
# RXF393_KIDNEY                                   19   11     7
# MCF7_BREAST                                     19    6    10
# T47D_BREAST                                     18   10     3
# MALME3M_SKIN                                    18    6     9
# SKMEL2_SKIN                                     17    8    11
# DU145_PROSTATE                                  17    5    14
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         17    9    10
# HCT15_LARGE_INTESTINE                           16   11     9
# M14_SKIN                                        16    7    14
# SKMEL28_SKIN                                    16    9    10
# CAKI1_KIDNEY                                    14   11    10
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        12    8    11
# total                                         1181  393   393

# %%
print(df.to_markdown())
# Out:
# |                                             |   train |   val |   test |
# |:--------------------------------------------|--------:|------:|-------:|
# | SF268_CENTRAL_NERVOUS_SYSTEM                |      29 |     4 |      4 |
# | KM12_LARGE_INTESTINE                        |      28 |     4 |      4 |
# | HCT116_LARGE_INTESTINE                      |      28 |     6 |      3 |
# | RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE |      27 |     3 |      7 |
# | OVCAR8_OVARY                                |      27 |     4 |      6 |
# | A498_KIDNEY                                 |      25 |     4 |      6 |
# | NCIH322_LUNG                                |      25 |     2 |      9 |
# | SKOV3_OVARY                                 |      24 |     8 |      3 |
# | SNB75_CENTRAL_NERVOUS_SYSTEM                |      24 |     7 |      5 |
# | SF295_CENTRAL_NERVOUS_SYSTEM                |      24 |     6 |      7 |
# | A549_LUNG                                   |      24 |     7 |      6 |
# | NCIH522_LUNG                                |      24 |     7 |      6 |
# | CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  |      24 |     8 |      5 |
# | NCIH460_LUNG                                |      24 |     6 |      7 |
# | ACHN_KIDNEY                                 |      24 |     7 |      6 |
# | U251MG_CENTRAL_NERVOUS_SYSTEM               |      24 |     7 |      6 |
# | OVCAR5_OVARY                                |      23 |    10 |      2 |
# | SF539_CENTRAL_NERVOUS_SYSTEM                |      23 |     7 |      7 |
# | UACC62_SKIN                                 |      23 |     5 |      8 |
# | UACC257_SKIN                                |      23 |     8 |      3 |
# | MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    |      23 |     6 |      7 |
# | COLO205_LARGE_INTESTINE                     |      23 |     7 |      5 |
# | OVCAR4_OVARY                                |      23 |     3 |     10 |
# | SN12C_KIDNEY                                |      23 |     7 |      7 |
# | MDAMB435S_SKIN                              |      23 |     7 |      5 |
# | HT29_LARGE_INTESTINE                        |      23 |     7 |      5 |
# | PC3_PROSTATE                                |      23 |     6 |      6 |
# | HOP62_LUNG                                  |      22 |     7 |      7 |
# | 786O_KIDNEY                                 |      22 |     9 |      5 |
# | TK10_KIDNEY                                 |      21 |     9 |      6 |
# | HOP92_LUNG                                  |      21 |     8 |      6 |
# | SW620_LARGE_INTESTINE                       |      21 |    10 |      5 |
# | LOXIMVI_SKIN                                |      21 |     6 |     10 |
# | NCIH23_LUNG                                 |      21 |     6 |     10 |
# | HS578T_BREAST                               |      20 |     6 |     10 |
# | NCIH226_LUNG                                |      20 |     9 |      8 |
# | K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     |      20 |     9 |      6 |
# | HCC2998_LARGE_INTESTINE                     |      20 |     3 |     13 |
# | SKMEL5_SKIN                                 |      19 |    11 |      6 |
# | IGROV1_OVARY                                |      19 |    10 |      8 |
# | BT549_BREAST                                |      19 |     7 |      7 |
# | MDAMB231_BREAST                             |      19 |    12 |      5 |
# | EKVX_LUNG                                   |      19 |     7 |      8 |
# | RXF393_KIDNEY                               |      19 |    11 |      7 |
# | MCF7_BREAST                                 |      19 |     6 |     10 |
# | T47D_BREAST                                 |      18 |    10 |      3 |
# | MALME3M_SKIN                                |      18 |     6 |      9 |
# | SKMEL2_SKIN                                 |      17 |     8 |     11 |
# | DU145_PROSTATE                              |      17 |     5 |     14 |
# | HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     |      17 |     9 |     10 |
# | HCT15_LARGE_INTESTINE                       |      16 |    11 |      9 |
# | M14_SKIN                                    |      16 |     7 |     14 |
# | SKMEL28_SKIN                                |      16 |     9 |     10 |
# | CAKI1_KIDNEY                                |      14 |    11 |     10 |
# | SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    |      12 |     8 |     11 |
# | total                                       |    1181 |   393 |    393 |
