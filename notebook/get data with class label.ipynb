# %%
import pandas as pd
import numpy as np
import random as rd

from tqdm import tqdm
from joblib import Parallel, delayed

# %%
# Create PubChem_id list
pubchem_id = pd.read_csv('../DrugCell/data_rcellminer/pubchem_id_by_nsc.csv', index_col=0).dropna()
pubchem_id
# Out:
#          PUBCHEM_ID
# 17         219123.0
# 295          4775.0
# 353      24180741.0
# 384      54599265.0
# 534      16685698.0
# ...             ...
# 760087      60780.0
# 760091    9941647.0
# 760423    9955951.0
# 761431   42611257.0
# 781406  127025628.0
#
# [16522 rows x 1 columns]

# %%
#  Get smiles from PubChem ID  https://pubchem.ncbi.nlm.nih.gov/idexchange/idexchange.cgi
smiles = pd.read_table('../DrugCell/data_rcellminer/smiles_from_PubchemID.txt', header=None)
smiles.index = pubchem_id.index
smiles = smiles.drop(0, axis=1)
smiles.columns = ['smiles']
smiles = smiles.to_dict()['smiles']

# %%
nci60Act = pd.read_csv('../data/nci60Act_ccle.csv', index_col=0)

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = nci60Act[i].reset_index().dropna()
    tmp.columns = ['nsc', 'drug_response']
    tmp['cell_line'] = [i]*len(tmp)
    base = pd.concat([
        base,
        tmp
    ])

# %%
class_nsc = pd.read_csv(
    '../DrugCell/data_rcellminer/class_by_nsc.csv',
)

# %%
class_nsc['MECHANISM'].value_counts()
# Out:
# Other          22895
# Kinase           483
# DNA              274
# HDAC              46
# TUBB              45
# Apoptosis         38
# HSP90             16
# PSM               13
# Ho                13
# Methylation       13
# BRD               11
# Acetalax           4
# Name: MECHANISM, dtype: int64

# %%
nsc_list = set(class_nsc['NSC'])
class_nsc = {class_nsc['NSC'][i] : class_nsc['MECHANISM'][i] for i in class_nsc.index}

# %%
base['label'] = [class_nsc[i] if i in nsc_list else None for i in base['nsc']]
base = base[base['label'] != 'Other'] \
    .reset_index(drop=True) \
    .drop('label', axis=1)
base['smiles'] = [smiles[i] if i in smiles.keys() else None for i in base.nsc]
base = base.dropna()
base = base.reset_index(drop=True)
base = base[['cell_line', 'smiles', 'drug_response']]

# %%
base
# Out:
#          cell_line                                             smiles  \
# 0      MCF7_BREAST  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 1      MCF7_BREAST                                    C1(=NC(=NN1)N)N
# 2      MCF7_BREAST  CC1C(C(C(C(O1)O[C@H]2CC[C@@]3([C@H]4CC[C@@]5([...
# 3      MCF7_BREAST  CC(=O)OC1CC2(C(CCC3(C2(CCC3C4=COC(=O)C=C4)O)C)...
# 4      MCF7_BREAST                     C1CN1C2=NC(=NC(=N2)N3CC3)N4CC4
# ...            ...                                                ...
# 16987  TK10_KIDNEY                     O1[As]2O[As]3O[As]1O[As](O2)O3
# 16988  TK10_KIDNEY  C[C@@H]1[C@H]([C@H](C[C@@H](O1)O[C@H]2CC[C@]3(...
# 16989  TK10_KIDNEY  CC1=C2[C@H](C(=O)[C@@]3([C@H](C[C@@H]4[C@](C3[...
# 16990  TK10_KIDNEY  C1=NC2=C(N=C(N=C2N1C3[C@H]([C@@H]([C@H](O3)CO)...
# 16991  TK10_KIDNEY  CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=C2C...
#
#        drug_response
# 0           0.703626
# 1           0.203035
# 2          -0.006210
# 3           0.061604
# 4           0.857356
# ...              ...
# 16987      -1.149281
# 16988       1.048326
# 16989      -1.222745
# 16990      -1.081749
# 16991      -0.594655
#
# [16992 rows x 3 columns]

# %%
len(set(base['cell_line']))
# Out:
# 57

# %%
len(set(base['smiles']))
# Out:
# 309

# %%
pd.DataFrame(base['cell_line'].value_counts())
# Out:
#                                              cell_line
# NCIH460_LUNG                                       309
# SF268_CENTRAL_NERVOUS_SYSTEM                       309
# OVCAR8_OVARY                                       308
# A549_LUNG                                          308
# SF295_CENTRAL_NERVOUS_SYSTEM                       308
# HCT116_LARGE_INTESTINE                             308
# SNB19_CENTRAL_NERVOUS_SYSTEM                       307
# HCT15_LARGE_INTESTINE                              307
# KM12_LARGE_INTESTINE                               306
# NCIH23_LUNG                                        306
# SN12C_KIDNEY                                       305
# SF539_CENTRAL_NERVOUS_SYSTEM                       305
# SKMEL5_SKIN                                        305
# SW620_LARGE_INTESTINE                              305
# OVCAR5_OVARY                                       304
# LOXIMVI_SKIN                                       304
# COLO205_LARGE_INTESTINE                            304
# U251MG_CENTRAL_NERVOUS_SYSTEM                      304
# NIHOVCAR3_OVARY                                    303
# ACHN_KIDNEY                                        302
# IGROV1_OVARY                                       302
# CAKI1_KIDNEY                                       302
# EKVX_LUNG                                          302
# HOP62_LUNG                                         302
# TK10_KIDNEY                                        302
# HT29_LARGE_INTESTINE                               301
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        301
# M14_SKIN                                           300
# UACC257_SKIN                                       300
# NCIH322_LUNG                                       299
# 786O_KIDNEY                                        299
# SKMEL28_SKIN                                       299
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           299
# UACC62_SKIN                                        299
# SKMEL2_SKIN                                        298
# NCIH522_LUNG                                       298
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            298
# RXF393_KIDNEY                                      296
# SKOV3_OVARY                                        295
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            295
# NCIH226_LUNG                                       294
# A498_KIDNEY                                        294
# OVCAR4_OVARY                                       293
# SNB75_CENTRAL_NERVOUS_SYSTEM                       293
# HCC2998_LARGE_INTESTINE                            293
# HOP92_LUNG                                         292
# PC3_PROSTATE                                       291
# MDAMB435S_SKIN                                     291
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         291
# DU145_PROSTATE                                     290
# MDAMB231_BREAST                                    288
# MALME3M_SKIN                                       287
# HS578T_BREAST                                      287
# MCF7_BREAST                                        286
# T47D_BREAST                                        275
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           272
# BT549_BREAST                                       271

# %%
pd.DataFrame(base['smiles'].value_counts())
# Out:
#                                                     smiles
# CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C(...      57
# CC1=C2[C@H](C(=O)[C@@]3([C@H](C[C@@H]4[C@]([C@H...      57
# CCOC1=CC2=C(C=C1)C3=C(C2=O)C4=C(C=C(C=C4)[N+](=...      57
# CN(C)CCCN1C2=C(C3=C(C1=O)C=C(C=C3)[N+](=O)[O-])...      57
# CCCCCCCCCCCCCCCCCCOP(=O)([O-])OC1CC[N+](CC1)(C)C        57
# ...                                                    ...
# CC(=O)OC1CC2(C(CCC3(C2(CCC3C4=COC(=O)C=C4)O)C)C...      45
# CC(=O)O[C@@H]1C[C@]2([C@@H](CCC2=O)C3=C1[C@]4([...      44
# CN(CC1=CC=CC=C1)CC(=C)C2=CC=C(C=C2)C(=O)NC3=CC=...      44
# C1CCC2(CC1)C(=O)N(C(=O)N2)CCN(CCCl)CCCl                 42
# C[C@]12CC[C@@H](CC1=CC[C@@H]3[C@@H]2CC[C@]4([C@...      39
#
# [309 rows x 1 columns]

# %%
indexes = list(base.index)
rd.Random(42).shuffle(indexes)

# %%
test = indexes[round(len(indexes)*0.8):]
tmp = indexes[:round(len(indexes)*0.8)]
val = tmp[:len(test)]
train = tmp[len(test):]

# %%
train = base.iloc[train]
test = base.iloc[test]
val = base.iloc[val]

# %%
print('train: ' + str(train.shape))
print('val: ' + str(val.shape))
print('test: ' + str(test.shape))
# Out:
# train: (10196, 3)
# val: (3398, 3)
# test: (3398, 3)

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train['cell_line'].value_counts()), 
        pd.DataFrame(val['cell_line'].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test['cell_line'].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
df
# Out:
#                                              train   val  test
# RXF393_KIDNEY                                  197    50    49
# COLO205_LARGE_INTESTINE                        196    59    49
# SF295_CENTRAL_NERVOUS_SYSTEM                   194    55    59
# OVCAR5_OVARY                                   193    52    59
# HCT15_LARGE_INTESTINE                          192    70    45
# A549_LUNG                                      192    56    60
# DU145_PROSTATE                                 191    52    47
# SKMEL28_SKIN                                   191    48    60
# OVCAR8_OVARY                                   190    61    57
# NIHOVCAR3_OVARY                                189    59    55
# NCIH322_LUNG                                   189    48    62
# M14_SKIN                                       189    50    61
# OVCAR4_OVARY                                   188    49    56
# NCIH460_LUNG                                   188    73    48
# U251MG_CENTRAL_NERVOUS_SYSTEM                  187    60    57
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       186    58    55
# UACC62_SKIN                                    186    52    61
# SF268_CENTRAL_NERVOUS_SYSTEM                   186    65    58
# NCIH23_LUNG                                    185    58    63
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    183    58    60
# IGROV1_OVARY                                   182    59    61
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        181    60    57
# MDAMB435S_SKIN                                 181    55    55
# 786O_KIDNEY                                    180    70    49
# SKMEL5_SKIN                                    179    55    71
# PC3_PROSTATE                                   178    71    42
# SW620_LARGE_INTESTINE                          178    57    70
# SNB75_CENTRAL_NERVOUS_SYSTEM                   178    71    44
# SNB19_CENTRAL_NERVOUS_SYSTEM                   178    56    73
# CAKI1_KIDNEY                                   177    56    69
# MCF7_BREAST                                    177    61    48
# ACHN_KIDNEY                                    177    64    61
# SN12C_KIDNEY                                   176    66    63
# HT29_LARGE_INTESTINE                           175    56    70
# MDAMB231_BREAST                                175    72    41
# HCC2998_LARGE_INTESTINE                        175    62    56
# LOXIMVI_SKIN                                   174    56    74
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        174    59    62
# KM12_LARGE_INTESTINE                           174    69    63
# TK10_KIDNEY                                    174    57    71
# HOP92_LUNG                                     174    56    62
# HCT116_LARGE_INTESTINE                         174    68    66
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     173    60    58
# SKMEL2_SKIN                                    173    58    67
# SF539_CENTRAL_NERVOUS_SYSTEM                   173    59    73
# EKVX_LUNG                                      172    74    56
# HOP62_LUNG                                     172    64    66
# A498_KIDNEY                                    171    63    60
# NCIH226_LUNG                                   169    56    69
# HS578T_BREAST                                  169    56    62
# NCIH522_LUNG                                   168    66    64
# T47D_BREAST                                    167    53    55
# UACC257_SKIN                                   164    67    69
# SKOV3_OVARY                                    163    62    70
# BT549_BREAST                                   161    52    58
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       160    59    53
# MALME3M_SKIN                                   158    60    69
# total                                        10196  3398  3398

# %%
test.to_csv(
    '../DrugCell/data_rcellminer/test_rcell_wo_other.txt', sep='\t', 
    header=None, index=None
)

val.to_csv(
    '../DrugCell/data_rcellminer/val_rcell_wo_other.txt', sep='\t', 
    header=None, index=None
)

train.to_csv(
    '../DrugCell/data_rcellminer/train_rcell_wo_other.txt', sep='\t', 
    header=None, index=None
)
