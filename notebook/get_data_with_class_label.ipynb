# %%
import pandas as pd
import numpy as np
import random as rd

from urllib.request import HTTPError
from tqdm import tqdm
from joblib import Parallel, delayed

# %% [markdown]
# # Read nci60byCell Line Table
#  Indexes are NSC and columns are Cell Lines' name

# %%
nci60Act = pd.read_csv("../data/nci60Act_ccle.csv", index_col=0)
cell2ind = list(pd.read_table("../DrugCell/data/cell2ind.txt", header=None)[1])
nci60Act = nci60Act[list(set(cell2ind) & set(nci60Act.columns))]
nci60Act
# Out:
#         MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACHN_KIDNEY  \
# 1                                       1.540716     1.657273
# 17                                      1.686372    -0.941890
# 89                                      0.549935    -0.144006
# 185                                     1.675353          NaN
# 295                                    -0.264586    -0.264586
# ...                                          ...          ...
# 900911                                 -0.167151    -0.167151
# 900922                                 -0.169786    -0.169786
# 900964                                 -0.158754    -0.158754
# 900974                                 -0.132453    -0.132453
# 921923                                  2.251157    -0.140812
#
#         U251MG_CENTRAL_NERVOUS_SYSTEM  MALME3M_SKIN  SKOV3_OVARY  \
# 1                           -0.266183     -0.233261    -0.868240
# 17                          -0.843055     -0.756130    -0.492953
# 89                          -0.093513      0.318373    -0.126557
# 185                         -0.171509     -0.917027    -2.151708
# 295                         -0.264586     -0.264586    -0.264586
# ...                               ...           ...          ...
# 900911                            NaN     -0.167151    -0.167151
# 900922                      -0.169786     -0.169786    -0.169786
# 900964                      -0.158754      1.610430    -0.158754
# 900974                      -0.132453     -0.132453    -0.132453
# 921923                       0.353673     -0.400587    -1.092623
#
#         MDAMB435S_SKIN  EKVX_LUNG  DU145_PROSTATE  A549_LUNG  \
# 1            -0.386710  -0.264901       -0.434885  -0.826223
# 17           -0.941890  -0.676210       -0.941890  -0.941890
# 89                 NaN  -0.063351             NaN  -0.433001
# 185                NaN  -0.147899             NaN   0.500858
# 295          -0.264586  -0.264586       -0.264586  -0.264586
# ...                ...        ...             ...        ...
# 900911       -0.167151  -0.167151       -0.167151  -0.167151
# 900922       -0.169786  -0.169786       -0.169786        NaN
# 900964       -0.158754  -0.158754             NaN  -0.158754
# 900974       -0.132453  -0.132453       -0.132453  -0.132453
# 921923        0.869488  -0.411450       -0.152586  -0.453344
#
#         CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ...  OVCAR8_OVARY  \
# 1                                         1.642456  ...     -0.413599
# 17                                        2.270240  ...     -0.572734
# 89                                        0.061246  ...      0.185498
# 185                                       1.675353  ...      0.095648
# 295                                      -0.264586  ...      3.362653
# ...                                            ...  ...           ...
# 900911                                   -0.167151  ...     -0.167151
# 900922                                   -0.169786  ...     -0.169786
# 900964                                   -0.158754  ...     -0.158754
# 900974                                   -0.132453  ...     -0.132453
# 921923                                    2.585790  ...     -0.443540
#
#         SW620_LARGE_INTESTINE  786O_KIDNEY  A498_KIDNEY  PC3_PROSTATE  \
# 1                    1.294131    -0.519867    -1.648059     -0.403983
# 17                  -1.029408     0.521200    -0.329639      1.302516
# 89                   0.658260     0.368433    -0.655707           NaN
# 185                  0.683279    -0.061612          NaN           NaN
# 295                 -0.264586     4.822657    -0.264586     -0.264586
# ...                       ...          ...          ...           ...
# 900911              -0.167151    -0.167151    -0.167151     -0.167151
# 900922              -0.169786    -0.169786    -0.169786     -0.169786
# 900964              -0.158754    -0.158754    -0.158754     -0.158754
# 900974              -0.132453    -0.132453    -0.132453     -0.132453
# 921923               0.390348     0.350261    -0.920821     -0.268102
#
#         UACC257_SKIN  CAKI1_KIDNEY  SF539_CENTRAL_NERVOUS_SYSTEM  \
# 1          -0.407149     -0.269717                     -0.380720
# 17         -0.061915      0.717851                      1.140166
# 89         -0.070365      0.743888                     -0.165433
# 185        -0.807890      1.675353                      0.230402
# 295        -0.264586     -0.264586                     -0.264586
# ...              ...           ...                           ...
# 900911     -0.167151     -0.167151                     -0.167151
# 900922     -0.169786     -0.169786                     -0.169786
# 900964     -0.158754     -0.158754                     -0.158754
# 900974     -0.132453     -0.132453                     -0.132453
# 921923     -0.240908     -0.559582                     -0.268661
#
#         HCT116_LARGE_INTESTINE  COLO205_LARGE_INTESTINE
# 1                     0.732038                 0.008989
# 17                   -0.941890                -0.041714
# 89                    0.347687                 0.152000
# 185                        NaN                 0.174485
# 295                  -0.264586                -0.264586
# ...                        ...                      ...
# 900911               -0.167151                -0.167151
# 900922               -0.169786                -0.169786
# 900964               -0.158754                      NaN
# 900974               -0.132453                -0.132453
# 921923               -0.194546                -0.213616
#
# [24047 rows x 55 columns]

# %% [markdown]
# # Create train data table format

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = nci60Act[i].reset_index().dropna()
    tmp.columns = ['NSC', 'drug_response']
    tmp['cell_line'] = [i]*len(tmp)
    base = pd.concat([
        base,
        tmp
    ])
base = base.reset_index(drop=True)

# %%
len(set(base['NSC']))
# Out:
# 24047

# %% [markdown]
# # Read class label

# %%
class_nsc = pd.read_csv('../DrugCell/data_rcellminer/class_by_nsc.csv')
class_nsc.sort_values('NSC')
# Out:
#           NSC MECHANISM
# 112         1     Other
# 1200       17     Other
# 21579      89     Other
# 1355      185     Other
# 2118      295     Other
# ...       ...       ...
# 22699  900911     Other
# 22877  900922     Other
# 22701  900964     Other
# 21608  900974     Other
# 20537  921923     Other
#
# [23851 rows x 2 columns]

# %% [markdown]
# # Unique number of cell lines for each class
# There are 274 cell lines of DNA class

# %%
class_nsc.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other          22895
# Kinase           483
# DNA              274
# HDAC              46
# TUBB              45
# Apoptosis         38
# HSP90             16
# Ho                13
# Methylation       13
# PSM               13
# BRD               11
# Acetalax           4
# dtype: int64

# %% [markdown]
# # Merge label to main table on NSC

# %%
base_label = base.merge(class_nsc, on='NSC')
base_label
# Out:
#             NSC  drug_response                                 cell_line  \
# 0             1       1.540716  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 1             1       1.657273                               ACHN_KIDNEY
# 2             1      -0.266183             U251MG_CENTRAL_NERVOUS_SYSTEM
# 3             1      -0.233261                              MALME3M_SKIN
# 4             1      -0.868240                               SKOV3_OVARY
# ...         ...            ...                                       ...
# 1209388  768570      -0.769549                              PC3_PROSTATE
# 1209389  768570      -0.769549                              UACC257_SKIN
# 1209390  768570      -0.769549                              CAKI1_KIDNEY
# 1209391  768570       0.776115                    HCT116_LARGE_INTESTINE
# 1209392  768570      -0.769549                   COLO205_LARGE_INTESTINE
#
#         MECHANISM
# 0           Other
# 1           Other
# 2           Other
# 3           Other
# 4           Other
# ...           ...
# 1209388     Other
# 1209389     Other
# 1209390     Other
# 1209391     Other
# 1209392     Other
#
# [1209393 rows x 4 columns]

# %% [markdown]
# # Merge SMILES to main table on NSC

# %%
smiles = pd.read_csv('../data/nsc_cid_smiles.csv')[['NSC', 'SMILES']].drop_duplicates()
base_smiles = base_label.merge(smiles, on='NSC').drop('NSC', axis=1)
base_smiles
# Out:
#         drug_response                                 cell_line MECHANISM  \
# 0            1.686372  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Other
# 1           -0.941890                               ACHN_KIDNEY     Other
# 2           -0.843055             U251MG_CENTRAL_NERVOUS_SYSTEM     Other
# 3           -0.756130                              MALME3M_SKIN     Other
# 4           -0.492953                               SKOV3_OVARY     Other
# ...               ...                                       ...       ...
# 877939      -0.310412                               786O_KIDNEY     Other
# 877940      -0.310412                              UACC257_SKIN     Other
# 877941      -0.310412                              CAKI1_KIDNEY     Other
# 877942      -0.310412                    HCT116_LARGE_INTESTINE     Other
# 877943      -0.310412                   COLO205_LARGE_INTESTINE     Other
#
#                                   SMILES
# 0       CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 1       CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 2       CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 3       CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 4       CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# ...                                  ...
# 877939         CC(=O)N1C=CC2=C1N=CN=C2Cl
# 877940         CC(=O)N1C=CC2=C1N=CN=C2Cl
# 877941         CC(=O)N1C=CC2=C1N=CN=C2Cl
# 877942         CC(=O)N1C=CC2=C1N=CN=C2Cl
# 877943         CC(=O)N1C=CC2=C1N=CN=C2Cl
#
# [877944 rows x 4 columns]

# %%
base_smiles.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other        858874
# DNA           11820
# Kinase         1988
# HDAC           1709
# TUBB           1679
# Ho              615
# Apoptosis       610
# HSP90           274
# PSM             212
# Acetalax        163
# dtype: int64

# %%
set(base_smiles['MECHANISM'])
# Out:
# {'Acetalax',
#  'Apoptosis',
#  'DNA',
#  'HDAC',
#  'HSP90',
#  'Ho',
#  'Kinase',
#  'Other',
#  'PSM',
#  'TUBB'}

# %% [markdown]
# # Select DNA

# %%
df_dna = base_smiles[base_smiles['MECHANISM'] == 'DNA'].reset_index(drop=True)[['cell_line', 'SMILES', 'drug_response']]

# %% [markdown]
# # This has 11820 datapoints

# %%
df_dna.drop_duplicates()
# Out:
#                                       cell_line  \
# 0      MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 1                                   ACHN_KIDNEY
# 2                 U251MG_CENTRAL_NERVOUS_SYSTEM
# 3                                  MALME3M_SKIN
# 4                                   SKOV3_OVARY
# ...                                         ...
# 11815                              UACC257_SKIN
# 11816                              CAKI1_KIDNEY
# 11817              SF539_CENTRAL_NERVOUS_SYSTEM
# 11818                    HCT116_LARGE_INTESTINE
# 11819                   COLO205_LARGE_INTESTINE
#
#                                                   SMILES  drug_response
# 0      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.598806
# 1      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.499337
# 2      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.351135
# 3      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -0.733147
# 4      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -1.444659
# ...                                                  ...            ...
# 11815  CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=...      -1.155968
# 11816  CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=...       0.991410
# 11817  CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=...       0.991410
# 11818  CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=...       0.902428
# 11819  CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=...       0.064041
#
# [11820 rows x 3 columns]

# %% [markdown]
# # 55 cell lines and 214 drugs

# %%
len(set(df_dna['cell_line']))
# Out:
# 55

# %%
len(set(df_dna['SMILES']))
# Out:
# 214

# %%
pd.DataFrame(df_dna['cell_line'].value_counts())
# Out:
#                                              cell_line
# OVCAR8_OVARY                                       222
# UACC62_SKIN                                        222
# U251MG_CENTRAL_NERVOUS_SYSTEM                      222
# OVCAR4_OVARY                                       222
# SKMEL28_SKIN                                       222
# EKVX_LUNG                                          222
# UACC257_SKIN                                       222
# A549_LUNG                                          222
# OVCAR5_OVARY                                       222
# SF295_CENTRAL_NERVOUS_SYSTEM                       222
# KM12_LARGE_INTESTINE                               222
# HT29_LARGE_INTESTINE                               221
# NCIH460_LUNG                                       221
# SF268_CENTRAL_NERVOUS_SYSTEM                       221
# NCIH23_LUNG                                        221
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           221
# HCT15_LARGE_INTESTINE                              221
# SW620_LARGE_INTESTINE                              221
# CAKI1_KIDNEY                                       221
# SF539_CENTRAL_NERVOUS_SYSTEM                       221
# HCT116_LARGE_INTESTINE                             221
# NCIH522_LUNG                                       220
# SNB75_CENTRAL_NERVOUS_SYSTEM                       220
# NCIH322_LUNG                                       220
# COLO205_LARGE_INTESTINE                            220
# LOXIMVI_SKIN                                       220
# MALME3M_SKIN                                       220
# SN12C_KIDNEY                                       220
# NCIH226_LUNG                                       219
# HOP62_LUNG                                         219
# IGROV1_OVARY                                       219
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            218
# SKMEL2_SKIN                                        218
# HCC2998_LARGE_INTESTINE                            218
# RXF393_KIDNEY                                      218
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        218
# HOP92_LUNG                                         217
# SKMEL5_SKIN                                        217
# SKOV3_OVARY                                        216
# A498_KIDNEY                                        216
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         215
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            213
# TK10_KIDNEY                                        209
# M14_SKIN                                           209
# ACHN_KIDNEY                                        208
# MCF7_BREAST                                        207
# 786O_KIDNEY                                        204
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           197
# PC3_PROSTATE                                       196
# DU145_PROSTATE                                     195
# MDAMB435S_SKIN                                     195
# MDAMB231_BREAST                                    195
# HS578T_BREAST                                      194
# T47D_BREAST                                        191
# BT549_BREAST                                       187

# %%
pd.DataFrame(df_dna['SMILES'].value_counts())
# Out:
#                                                     SMILES
# C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)O                     110
# CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C(...     110
# CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=C(C=CC(=C5CN(C)...     110
# C1C(C(OC1N2C=NC3=C2NC(=NC3=S)N)CO)O                    110
# COC1=C(C=CC(=C1)NS(=O)(=O)C)NC2=C3C=CC=CC3=NC4=...     110
# ...                                                    ...
# C1C(C(OC1N2C=NC(=NC2=O)N)CO)O                           43
# C1CC(OC1CO)N2C=CC(=NC2=O)N                              42
# C1=CC=C(C(=C1)C(=O)NCCCC(C(=O)O)NC(=O)C2=CC=C(C...      41
# C1CCC2(CC1)C(=O)N(C(=O)N2)CCN(CCCl)CCCl                 40
# C1=CC=C(C(=C1)C(C2=CC=C(C=C2)Cl)C(Cl)Cl)Cl              39
#
# [214 rows x 1 columns]

# %%
indexes = list(df_dna.index)
rd.Random(42).shuffle(indexes)

# %%
test = indexes[round(len(indexes)*0.8):]
tmp = indexes[:round(len(indexes)*0.8)]
val = tmp[:len(test)]
train = tmp[len(test):]

# %%
train = df_dna.iloc[train]
test = df_dna.iloc[test]
val = df_dna.iloc[val]

# %%
print('train: ' + str(train.shape))
print('val: ' + str(val.shape))
print('test: ' + str(test.shape))
# Out:
# train: (7092, 3)
# val: (2364, 3)
# test: (2364, 3)

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train['cell_line'].value_counts()), 
        pd.DataFrame(val['cell_line'].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test['cell_line'].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
df
# Out:
#                                              train   val  test
# NCIH322_LUNG                                   146    38    36
# LOXIMVI_SKIN                                   145    41    34
# HT29_LARGE_INTESTINE                           143    43    35
# NCIH460_LUNG                                   142    27    52
# A498_KIDNEY                                    141    36    39
# IGROV1_OVARY                                   141    34    44
# EKVX_LUNG                                      140    36    46
# U251MG_CENTRAL_NERVOUS_SYSTEM                  139    51    32
# CAKI1_KIDNEY                                   139    42    40
# COLO205_LARGE_INTESTINE                        138    45    37
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     138    34    43
# HOP92_LUNG                                     135    44    38
# UACC62_SKIN                                    135    48    39
# NCIH226_LUNG                                   135    42    42
# HOP62_LUNG                                     134    38    47
# HCT15_LARGE_INTESTINE                          134    33    54
# SF268_CENTRAL_NERVOUS_SYSTEM                   133    40    48
# 786O_KIDNEY                                    133    30    41
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       133    39    49
# OVCAR8_OVARY                                   132    45    45
# NCIH23_LUNG                                    132    43    46
# SKMEL5_SKIN                                    131    38    48
# SF539_CENTRAL_NERVOUS_SYSTEM                   130    45    46
# KM12_LARGE_INTESTINE                           130    52    40
# NCIH522_LUNG                                   129    43    48
# RXF393_KIDNEY                                  129    47    42
# SNB75_CENTRAL_NERVOUS_SYSTEM                   129    53    38
# SKMEL2_SKIN                                    128    49    41
# SF295_CENTRAL_NERVOUS_SYSTEM                   128    46    48
# TK10_KIDNEY                                    128    39    42
# MDAMB231_BREAST                                128    33    34
# MALME3M_SKIN                                   127    42    51
# SW620_LARGE_INTESTINE                          127    45    49
# OVCAR4_OVARY                                   127    39    56
# M14_SKIN                                       127    50    32
# MCF7_BREAST                                    127    42    38
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    126    50    42
# SN12C_KIDNEY                                   126    47    47
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        126    45    42
# OVCAR5_OVARY                                   125    52    45
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        125    50    43
# PC3_PROSTATE                                   125    30    41
# SKMEL28_SKIN                                   124    46    52
# DU145_PROSTATE                                 123    30    42
# ACHN_KIDNEY                                    123    39    46
# A549_LUNG                                      123    55    44
# HCT116_LARGE_INTESTINE                         122    48    51
# SKOV3_OVARY                                    122    47    47
# UACC257_SKIN                                   120    54    48
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       117    46    34
# HCC2998_LARGE_INTESTINE                        116    48    54
# MDAMB435S_SKIN                                 113    40    42
# HS578T_BREAST                                  113    48    33
# T47D_BREAST                                    106    51    34
# BT549_BREAST                                   104    46    37
# total                                         7092  2364  2364

# %%
test.to_csv(
    '../DrugCell/data_rcellminer/test_DNA.txt', sep='\t', 
    header=None, index=None
)

val.to_csv(
    '../DrugCell/data_rcellminer/val_DNA.txt', sep='\t', 
    header=None, index=None
)

train.to_csv(
    '../DrugCell/data_rcellminer/train_DNA.txt', sep='\t', 
    header=None, index=None
)
