# %%
import pandas as pd
import numpy as np
import random as rd

from urllib.request import HTTPError
from tqdm import tqdm
from joblib import Parallel, delayed

# %% [markdown]
# # Read nci60byCell Line Table
#  Indexes are NSC and columns are Cell Lines' name

# %%
nci60Act = pd.read_csv('../data/nci60Act_ccle.csv', index_col=0)
nci60Act
# Out:
#         MCF7_BREAST  MDAMB231_BREAST  HS578T_BREAST  BT549_BREAST  \
# 1         -0.271314        -0.303539      -0.815183     -0.231499
# 17        -0.354110        -0.304675      -0.222024      1.483613
# 89              NaN              NaN            NaN           NaN
# 185             NaN              NaN            NaN           NaN
# 295       -0.264586        -0.264586      -0.264586     -0.264586
# ...             ...              ...            ...           ...
# 900911    -0.167151        -0.167151      -0.167151     -0.167151
# 900922    -0.169786        -0.169786      -0.169786     -0.169786
# 900964    -0.158754        -0.158754      -0.158754     -0.158754
# 900974    -0.132453        -0.132453      -0.132453           NaN
# 921923     0.513889        -0.600293      -0.816154     -0.604513
#
#         T47D_BREAST  SF268_CENTRAL_NERVOUS_SYSTEM  \
# 1          1.934731                     -0.357577
# 17         1.509397                      0.335572
# 89              NaN                     -0.184194
# 185             NaN                      0.539343
# 295       -0.264586                     -0.264586
# ...             ...                           ...
# 900911    -0.167151                     -0.167151
# 900922    -0.169786                     -0.169786
# 900964    -0.158754                     -0.158754
# 900974    -0.132453                     -0.132453
# 921923          NaN                     -0.126943
#
#         SF295_CENTRAL_NERVOUS_SYSTEM  SF539_CENTRAL_NERVOUS_SYSTEM  \
# 1                          -0.719253                     -0.380720
# 17                          0.424922                      1.140166
# 89                         -1.429903                     -0.165433
# 185                              NaN                      0.230402
# 295                        -0.264586                     -0.264586
# ...                              ...                           ...
# 900911                     -0.167151                     -0.167151
# 900922                     -0.169786                     -0.169786
# 900964                     -0.158754                     -0.158754
# 900974                     -0.132453                     -0.132453
# 921923                     -0.961518                     -0.268661
#
#         SNB19_CENTRAL_NERVOUS_SYSTEM  SNB75_CENTRAL_NERVOUS_SYSTEM  ...  \
# 1                          -1.281589                     -0.175915  ...
# 17                         -0.941890                      0.330808  ...
# 89                         -1.429903                     -0.216723  ...
# 185                        -0.765829                     -1.125208  ...
# 295                        -0.264586                     -0.264586  ...
# ...                              ...                           ...  ...
# 900911                     -0.167151                     -0.167151  ...
# 900922                     -0.169786                     -0.169786  ...
# 900964                     -0.158754                     -0.158754  ...
# 900974                     -0.132453                     -0.132453  ...
# 921923                     -0.927258                           NaN  ...
#
#         SKOV3_OVARY  PC3_PROSTATE  DU145_PROSTATE  786O_KIDNEY  A498_KIDNEY  \
# 1         -0.868240     -0.403983       -0.434885    -0.519867    -1.648059
# 17        -0.492953      1.302516       -0.941890     0.521200    -0.329639
# 89        -0.126557           NaN             NaN     0.368433    -0.655707
# 185       -2.151708           NaN             NaN    -0.061612          NaN
# 295       -0.264586     -0.264586       -0.264586     4.822657    -0.264586
# ...             ...           ...             ...          ...          ...
# 900911    -0.167151     -0.167151       -0.167151    -0.167151    -0.167151
# 900922    -0.169786     -0.169786       -0.169786    -0.169786    -0.169786
# 900964    -0.158754     -0.158754             NaN    -0.158754    -0.158754
# 900974    -0.132453     -0.132453       -0.132453    -0.132453    -0.132453
# 921923    -1.092623     -0.268102       -0.152586     0.350261    -0.920821
#
#         ACHN_KIDNEY  CAKI1_KIDNEY  RXF393_KIDNEY  SN12C_KIDNEY  TK10_KIDNEY
# 1          1.657273     -0.269717       0.002290     -0.390689    -0.379420
# 17        -0.941890      0.717851      -0.239018     -0.315533    -0.761559
# 89        -0.144006      0.743888      -0.435620     -0.184805    -0.101929
# 185             NaN      1.675353       0.918722      1.391604    -0.904724
# 295       -0.264586     -0.264586      -0.264586     -0.264586    -0.264586
# ...             ...           ...            ...           ...          ...
# 900911    -0.167151     -0.167151       1.594059     -0.167151    -0.167151
# 900922    -0.169786     -0.169786      -0.169786     -0.169786    -0.169786
# 900964    -0.158754     -0.158754      -0.158754     -0.158754    -0.158754
# 900974    -0.132453     -0.132453            NaN     -0.132453    -0.132453
# 921923    -0.140812     -0.559582      -1.009885      0.705388     1.538064
#
# [24047 rows x 57 columns]

# %% [markdown]
# # Create train data table format

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = nci60Act[i].reset_index().dropna()
    tmp.columns = ['NSC', 'drug_response']
    tmp['cell_line'] = [i]*len(tmp)
    base = pd.concat([
        base,
        tmp
    ])
base = base.reset_index(drop=True)

# %%
base
# Out:
#             NSC  drug_response    cell_line
# 0             1      -0.271314  MCF7_BREAST
# 1            17      -0.354110  MCF7_BREAST
# 2           295      -0.264586  MCF7_BREAST
# 3           353       0.744838  MCF7_BREAST
# 4           384      -0.041323  MCF7_BREAST
# ...         ...            ...          ...
# 1266165  900911      -0.167151  TK10_KIDNEY
# 1266166  900922      -0.169786  TK10_KIDNEY
# 1266167  900964      -0.158754  TK10_KIDNEY
# 1266168  900974      -0.132453  TK10_KIDNEY
# 1266169  921923       1.538064  TK10_KIDNEY
#
# [1266170 rows x 3 columns]

# %% [markdown]
# # Read class label

# %%
class_nsc = pd.read_csv('../DrugCell/data_rcellminer/class_by_nsc.csv')
class_nsc
# Out:
#           NSC    MECHANISM
# 0      762419        Other
# 1      719239        Other
# 2      777573        Other
# 3      774651        Other
# 4      765776        Other
# ...       ...          ...
# 23846  810341  Methylation
# 23847  808507  Methylation
# 23848  785299  Methylation
# 23849  790865  Methylation
# 23850  780404  Methylation
#
# [23851 rows x 2 columns]

# %% [markdown]
# # Unique number of cell lines for each class
# There are 274 cell lines of DNA class

# %%
class_nsc.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other          22895
# Kinase           483
# DNA              274
# HDAC              46
# TUBB              45
# Apoptosis         38
# HSP90             16
# Ho                13
# Methylation       13
# PSM               13
# BRD               11
# Acetalax           4
# dtype: int64

# %% [markdown]
# # Merge label to main table on NSC

# %%
base_label = base.merge(class_nsc, on='NSC')
base_label
# Out:
#             NSC  drug_response        cell_line MECHANISM
# 0             1      -0.271314      MCF7_BREAST     Other
# 1             1      -0.303539  MDAMB231_BREAST     Other
# 2             1      -0.815183    HS578T_BREAST     Other
# 3             1      -0.231499     BT549_BREAST     Other
# 4             1       1.934731      T47D_BREAST     Other
# ...         ...            ...              ...       ...
# 1255376  626744       1.719118     OVCAR4_OVARY     Other
# 1255377  626744      -1.697994     OVCAR5_OVARY     Other
# 1255378  626744       1.419889     OVCAR8_OVARY     Other
# 1255379  626744       0.681835      SKOV3_OVARY     Other
# 1255380  626744       3.868100      A498_KIDNEY     Other
#
# [1255381 rows x 4 columns]

# %% [markdown]
# # Get SMILES from pubchem id

# %%
def get_SMILES_from_pubchemID(pubchem_id):
    """
    Get the SMILES from pubchem_id using PubChem API

    Parameters
    ----------

    pubchem_id : pd.DataFrame

    Returns
    -------

    df : pd.DataFrame

    """

    df = pd.DataFrame()
    for i in tqdm(
        list(range(500, pubchem_id.shape[0], 500)) + [pubchem_id.shape[0]]
    ):
        cid = ""
        for j in pubchem_id["CID"][i - 500 : i]:
            cid = str(j) + "," + cid

        try:
            df = pd.concat(
                [
                    pd.read_csv(
                        "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/"
                        + cid
                        + "/property/CanonicalSMILES/CSV"
                    ),
                    df,
                ]
            )
        except HTTPError as e:
            # if we got error, devided by more small number to get where we got the error.
            # Not sure why I didn't get error again though...
            for i in np.array_split(np.array(cid.split(",")), 2):
                t = ""
                for l in i:
                    t += l + ","
                try:
                    df = pd.concat(
                        [
                            pd.read_csv(
                                "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/"
                                + t
                                + "/property/CanonicalSMILES/CSV"
                            ),
                            df,
                        ]
                    )
                except HTTPError as e:
                    if e.code == 403:
                        print("error")
    df = (
        df.drop_duplicates("CanonicalSMILES")
        .sort_values("CID")
        .reset_index(drop=True)
    )
    df = pubchem_id.reset_index().merge(df, on="CID")[
        ["index", "CanonicalSMILES"]
    ]
    df.columns = ["NSC", "SMILES"]

    return df

# %%
pubchem_id = pd.read_csv('../data/nci60PubChemID.csv', index_col=0).dropna()
pubchem_id = pubchem_id.sort_values('PUBCHEM_ID')
pubchem_id.columns = ['CID']

# %%
df = get_SMILES_from_pubchemID(pubchem_id)
# Out:
# 100%|██████████| 34/34 [00:10<00:00,  3.26it/s]

# %% [markdown]
# # Merge SMILES to main table on NSC

# %%
base_smiles = base_label.merge(df, on='NSC').drop('NSC', axis=1)
base_smiles
# Out:
#         drug_response        cell_line MECHANISM  \
# 0           -0.354110      MCF7_BREAST     Other
# 1           -0.304675  MDAMB231_BREAST     Other
# 2           -0.222024    HS578T_BREAST     Other
# 3            1.483613     BT549_BREAST     Other
# 4            1.509397      T47D_BREAST     Other
# ...               ...              ...       ...
# 854144       1.719118     OVCAR4_OVARY     Other
# 854145      -1.697994     OVCAR5_OVARY     Other
# 854146       1.419889     OVCAR8_OVARY     Other
# 854147       0.681835      SKOV3_OVARY     Other
# 854148       3.868100      A498_KIDNEY     Other
#
#                                                SMILES
# 0                    CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 1                    CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 2                    CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 3                    CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 4                    CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# ...                                               ...
# 854144  CC1C(N(C(CC(=O)N1)C2=CC=CC=C2)N=O)C3=CC=CC=C3
# 854145  CC1C(N(C(CC(=O)N1)C2=CC=CC=C2)N=O)C3=CC=CC=C3
# 854146  CC1C(N(C(CC(=O)N1)C2=CC=CC=C2)N=O)C3=CC=CC=C3
# 854147  CC1C(N(C(CC(=O)N1)C2=CC=CC=C2)N=O)C3=CC=CC=C3
# 854148  CC1C(N(C(CC(=O)N1)C2=CC=CC=C2)N=O)C3=CC=CC=C3
#
# [854149 rows x 4 columns]

# %% [markdown]
# # Select DNA

# %%
df = base_smiles[base_smiles['MECHANISM'] == 'DNA'].reset_index(drop=True)[['cell_line', 'SMILES', 'drug_response']]

# %% [markdown]
# # This has 6779 datapoints

# %%
df
# Out:
#             cell_line                                             SMILES  \
# 0         MCF7_BREAST  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 1     MDAMB231_BREAST  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 2       HS578T_BREAST  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 3        BT549_BREAST  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 4         T47D_BREAST  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# ...               ...                                                ...
# 6774      ACHN_KIDNEY  CN(C)CCCN1C2=C3C(=C(C=C2)[N+](=O)[O-])NC4=C(C3...
# 6775     CAKI1_KIDNEY  CN(C)CCCN1C2=C3C(=C(C=C2)[N+](=O)[O-])NC4=C(C3...
# 6776    RXF393_KIDNEY  CN(C)CCCN1C2=C3C(=C(C=C2)[N+](=O)[O-])NC4=C(C3...
# 6777     SN12C_KIDNEY  CN(C)CCCN1C2=C3C(=C(C=C2)[N+](=O)[O-])NC4=C(C3...
# 6778      TK10_KIDNEY  CN(C)CCCN1C2=C3C(=C(C=C2)[N+](=O)[O-])NC4=C(C3...
#
#       drug_response
# 0          0.703626
# 1         -1.219032
# 2         -1.892792
# 3         -0.877267
# 4         -1.156158
# ...             ...
# 6774       0.626710
# 6775      -0.085429
# 6776      -0.193796
# 6777       1.555142
# 6778      -0.771586
#
# [6779 rows x 3 columns]

# %% [markdown]
# # 57 cell lines and 122 drugs

# %%
len(set(df['cell_line']))
# Out:
# 57

# %%
len(set(df['SMILES']))
# Out:
# 122

# %%
pd.DataFrame(df['cell_line'].value_counts())
# Out:
#                                              cell_line
# SKMEL28_SKIN                                       122
# U251MG_CENTRAL_NERVOUS_SYSTEM                      122
# OVCAR8_OVARY                                       122
# NIHOVCAR3_OVARY                                    122
# KM12_LARGE_INTESTINE                               122
# HT29_LARGE_INTESTINE                               122
# HCT116_LARGE_INTESTINE                             122
# UACC257_SKIN                                       122
# OVCAR4_OVARY                                       122
# UACC62_SKIN                                        122
# NCIH460_LUNG                                       122
# SNB19_CENTRAL_NERVOUS_SYSTEM                       122
# SF539_CENTRAL_NERVOUS_SYSTEM                       122
# SF295_CENTRAL_NERVOUS_SYSTEM                       122
# SF268_CENTRAL_NERVOUS_SYSTEM                       122
# A549_LUNG                                          122
# EKVX_LUNG                                          122
# SN12C_KIDNEY                                       122
# OVCAR5_OVARY                                       122
# NCIH522_LUNG                                       121
# IGROV1_OVARY                                       121
# MALME3M_SKIN                                       121
# LOXIMVI_SKIN                                       121
# A498_KIDNEY                                        121
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           121
# NCIH23_LUNG                                        121
# SW620_LARGE_INTESTINE                              121
# HCT15_LARGE_INTESTINE                              121
# COLO205_LARGE_INTESTINE                            121
# CAKI1_KIDNEY                                       121
# SKMEL5_SKIN                                        120
# HCC2998_LARGE_INTESTINE                            120
# SNB75_CENTRAL_NERVOUS_SYSTEM                       120
# HOP62_LUNG                                         120
# NCIH322_LUNG                                       120
# NCIH226_LUNG                                       120
# ACHN_KIDNEY                                        119
# RXF393_KIDNEY                                      119
# TK10_KIDNEY                                        119
# SKMEL2_SKIN                                        119
# M14_SKIN                                           119
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            119
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        119
# HOP92_LUNG                                         118
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         117
# SKOV3_OVARY                                        116
# 786O_KIDNEY                                        116
# MCF7_BREAST                                        116
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            114
# MDAMB435S_SKIN                                     112
# PC3_PROSTATE                                       112
# DU145_PROSTATE                                     111
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           111
# MDAMB231_BREAST                                    110
# HS578T_BREAST                                      110
# T47D_BREAST                                        109
# BT549_BREAST                                       105

# %%
pd.DataFrame(df['SMILES'].value_counts())
# Out:
#                                                     SMILES
# CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C(...      57
# CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C5=CC=CC=C5N=C4C3...      57
# CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C5=CC=CC=C5N=C4C3...      57
# CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C5=CC=CC=C5N=C4C3...      57
# CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3=...      57
# ...                                                    ...
# CC1=C(C=CC(=C1)N(CCOS(=O)(=O)C)CCOS(=O)(=O)C)C=O        48
# CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C3=C2)N=C5C=C(C(=...      45
# CC1=C2C=C[N+](=CC2=C(C3=C1NC4=CC=CC=C43)C)C.[I-]        45
# C1C(ON=C1Cl)C(C(=O)O)N                                  45
# C1CCC2(CC1)C(=O)N(C(=O)N2)CCN(CCCl)CCCl                 42
#
# [122 rows x 1 columns]

# %%
indexes = list(df.index)
rd.Random(42).shuffle(indexes)

# %%
test = indexes[round(len(indexes)*0.8):]
tmp = indexes[:round(len(indexes)*0.8)]
val = tmp[:len(test)]
train = tmp[len(test):]

# %%
train = df.iloc[train]
test = df.iloc[test]
val = df.iloc[val]

# %%
print('train: ' + str(train.shape))
print('val: ' + str(val.shape))
print('test: ' + str(test.shape))
# Out:
# train: (4067, 3)
# val: (1356, 3)
# test: (1356, 3)

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train['cell_line'].value_counts()), 
        pd.DataFrame(val['cell_line'].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test['cell_line'].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
df
# Out:
#                                              train   val  test
# EKVX_LUNG                                       84    17    21
# SKMEL2_SKIN                                     82    15    22
# NCIH460_LUNG                                    82    20    20
# M14_SKIN                                        81    21    17
# UACC257_SKIN                                    77    21    24
# SW620_LARGE_INTESTINE                           77    23    21
# NCIH522_LUNG                                    77    15    29
# ACHN_KIDNEY                                     76    22    21
# DU145_PROSTATE                                  76    17    18
# HT29_LARGE_INTESTINE                            75    23    24
# HOP62_LUNG                                      75    27    18
# SF268_CENTRAL_NERVOUS_SYSTEM                    75    28    19
# HCT116_LARGE_INTESTINE                          75    20    27
# UACC62_SKIN                                     75    23    24
# NCIH226_LUNG                                    75    20    25
# OVCAR8_OVARY                                    75    30    17
# CAKI1_KIDNEY                                    75    23    23
# NCIH322_LUNG                                    74    24    22
# MCF7_BREAST                                     74    17    25
# A498_KIDNEY                                     74    22    25
# COLO205_LARGE_INTESTINE                         74    27    20
# SNB19_CENTRAL_NERVOUS_SYSTEM                    74    19    29
# SKMEL28_SKIN                                    73    30    19
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        73    17    21
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     73    23    23
# LOXIMVI_SKIN                                    72    28    21
# SN12C_KIDNEY                                    72    27    23
# KM12_LARGE_INTESTINE                            72    28    22
# HS578T_BREAST                                   71    18    21
# HCC2998_LARGE_INTESTINE                         71    21    28
# SNB75_CENTRAL_NERVOUS_SYSTEM                    70    23    27
# A549_LUNG                                       70    24    28
# SF539_CENTRAL_NERVOUS_SYSTEM                    70    28    24
# OVCAR4_OVARY                                    70    30    22
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         70    24    25
# HOP92_LUNG                                      70    28    20
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        69    26    26
# MDAMB231_BREAST                                 69    22    19
# 786O_KIDNEY                                     69    26    21
# U251MG_CENTRAL_NERVOUS_SYSTEM                   69    33    20
# MALME3M_SKIN                                    69    22    30
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      68    24    25
# SF295_CENTRAL_NERVOUS_SYSTEM                    68    33    21
# TK10_KIDNEY                                     68    27    24
# NIHOVCAR3_OVARY                                 67    28    27
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         67    22    25
# IGROV1_OVARY                                    66    25    30
# SKOV3_OVARY                                     66    25    25
# SKMEL5_SKIN                                     65    24    31
# PC3_PROSTATE                                    64    23    25
# MDAMB435S_SKIN                                  64    23    25
# HCT15_LARGE_INTESTINE                           64    32    25
# RXF393_KIDNEY                                   64    26    29
# OVCAR5_OVARY                                    64    31    27
# NCIH23_LUNG                                     63    30    28
# BT549_BREAST                                    63    16    26
# T47D_BREAST                                     62    15    32
# total                                         4067  1356  1356

# %%
# test.to_csv(
#     '../DrugCell/data_rcellminer/test_rcell_wo_other.txt', sep='\t', 
#     header=None, index=None
# )

# val.to_csv(
#     '../DrugCell/data_rcellminer/val_rcell_wo_other.txt', sep='\t', 
#     header=None, index=None
# )

# train.to_csv(
#     '../DrugCell/data_rcellminer/train_rcell_wo_other.txt', sep='\t', 
#     header=None, index=None
# )
