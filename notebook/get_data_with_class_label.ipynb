# %%
import pandas as pd
import numpy as np
import random as rd

from urllib.request import HTTPError
from tqdm import tqdm
from joblib import Parallel, delayed

# %% [markdown]
# # Read nci60byCell Line Table
#  Indexes are NSC and columns are Cell Lines' name

# %%
nci60Act = pd.read_csv("../data/nci60Act_ccle.csv", index_col=0)
cell2ind = list(pd.read_table("../DrugCell/data/cell2ind.txt", header=None)[1])
nci60Act = nci60Act[list(set(cell2ind) & set(nci60Act.columns))]
nci60Act
# Out:
#         786O_KIDNEY  HT29_LARGE_INTESTINE  NCIH322_LUNG  \
# 1         -0.519867             -0.918047     -0.802747
# 17         0.521200             -0.941890     -0.786423
# 89         0.368433             -0.487137     -1.429903
# 185       -0.061612             -0.283713      0.332463
# 295        4.822657             -0.264586     -0.264586
# ...             ...                   ...           ...
# 900911    -0.167151             -0.167151     -0.167151
# 900922    -0.169786             -0.169786     -0.169786
# 900964    -0.158754             -0.158754     -0.158754
# 900974    -0.132453             -0.132453     -0.132453
# 921923     0.350261             -0.560096     -0.506380
#
#         SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  T47D_BREAST  \
# 1                                       0.325208     1.934731
# 17                                      0.621871     1.509397
# 89                                     -0.222065          NaN
# 185                                          NaN          NaN
# 295                                     2.919066    -0.264586
# ...                                          ...          ...
# 900911                                 -0.167151    -0.167151
# 900922                                 -0.169786    -0.169786
# 900964                                 -0.158754    -0.158754
# 900974                                 -0.132453    -0.132453
# 921923                                  1.350827          NaN
#
#         SF295_CENTRAL_NERVOUS_SYSTEM  RXF393_KIDNEY  NCIH522_LUNG  \
# 1                          -0.719253       0.002290      1.914094
# 17                          0.424922      -0.239018      1.832493
# 89                         -1.429903      -0.435620      5.026869
# 185                              NaN       0.918722           NaN
# 295                        -0.264586      -0.264586     -0.264586
# ...                              ...            ...           ...
# 900911                     -0.167151       1.594059           NaN
# 900922                     -0.169786      -0.169786     -0.169786
# 900964                     -0.158754      -0.158754     -0.158754
# 900974                     -0.132453            NaN     -0.132453
# 921923                     -0.961518      -1.009885      0.682694
#
#         HS578T_BREAST  NCIH226_LUNG  ...  HCC2998_LARGE_INTESTINE  \
# 1           -0.815183     -1.164555  ...                -0.490868
# 17          -0.222024      0.100266  ...                -0.941890
# 89                NaN     -0.605885  ...                -0.163225
# 185               NaN     -3.502638  ...                 0.476776
# 295         -0.264586     -0.264586  ...                -0.264586
# ...               ...           ...  ...                      ...
# 900911      -0.167151     -0.167151  ...                -0.167151
# 900922      -0.169786     -0.169786  ...                 2.343934
# 900964      -0.158754     -0.158754  ...                -0.158754
# 900974      -0.132453     -0.132453  ...                 7.417381
# 921923      -0.816154     -0.246742  ...                -0.633673
#
#         HCT15_LARGE_INTESTINE  OVCAR8_OVARY  SF539_CENTRAL_NERVOUS_SYSTEM  \
# 1                   -0.082824     -0.413599                     -0.380720
# 17                  -0.630920     -0.572734                      1.140166
# 89                   0.236371      0.185498                     -0.165433
# 185                 -0.059621      0.095648                      0.230402
# 295                 -0.264586      3.362653                     -0.264586
# ...                       ...           ...                           ...
# 900911              -0.167151     -0.167151                     -0.167151
# 900922              -0.169786     -0.169786                     -0.169786
# 900964              -0.158754     -0.158754                     -0.158754
# 900974              -0.132453     -0.132453                     -0.132453
# 921923              -0.368297     -0.443540                     -0.268661
#
#         RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  SW620_LARGE_INTESTINE  \
# 1                                          1.504554               1.294131
# 17                                         1.698491              -1.029408
# 89                                         1.191198               0.658260
# 185                                       -0.024337               0.683279
# 295                                             NaN              -0.264586
# ...                                             ...                    ...
# 900911                                     6.930661              -0.167151
# 900922                                    -0.169786              -0.169786
# 900964                                    -0.158754              -0.158754
# 900974                                    -0.132453              -0.132453
# 921923                                          NaN               0.390348
#
#         MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  IGROV1_OVARY  NCIH460_LUNG  \
# 1                                       1.540716      0.149074     -0.700613
# 17                                      1.686372      1.353076     -0.941890
# 89                                      0.549935     -0.181827     -0.183471
# 185                                     1.675353     -0.852569           NaN
# 295                                    -0.264586     -0.264586     -0.264586
# ...                                          ...           ...           ...
# 900911                                 -0.167151     -0.167151     -0.167151
# 900922                                 -0.169786     -0.169786           NaN
# 900964                                 -0.158754     -0.158754     -0.158754
# 900974                                 -0.132453     -0.132453     -0.132453
# 921923                                  2.251157     -0.251762      0.794123
#
#         CAKI1_KIDNEY
# 1          -0.269717
# 17          0.717851
# 89          0.743888
# 185         1.675353
# 295        -0.264586
# ...              ...
# 900911     -0.167151
# 900922     -0.169786
# 900964     -0.158754
# 900974     -0.132453
# 921923     -0.559582
#
# [24047 rows x 55 columns]

# %% [markdown]
# # Create train data table format

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = nci60Act[i].reset_index().dropna()
    tmp.columns = ['NSC', 'drug_response']
    tmp['cell_line'] = [i]*len(tmp)
    base = pd.concat([
        base,
        tmp
    ])
base = base.reset_index(drop=True)

# %%
len(set(base['NSC']))
# Out:
# 24047

# %% [markdown]
# # Read class label

# %%
class_nsc = pd.read_csv('../DrugCell/data_rcellminer/class_by_nsc.csv')
class_nsc.sort_values('NSC')
# Out:
#           NSC MECHANISM
# 112         1     Other
# 1200       17     Other
# 21579      89     Other
# 1355      185     Other
# 2118      295     Other
# ...       ...       ...
# 22699  900911     Other
# 22877  900922     Other
# 22701  900964     Other
# 21608  900974     Other
# 20537  921923     Other
#
# [23851 rows x 2 columns]

# %% [markdown]
# # Unique number of cell lines for each class
# There are 274 cell lines of DNA class

# %%
class_nsc.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other          22895
# Kinase           483
# DNA              274
# HDAC              46
# TUBB              45
# Apoptosis         38
# HSP90             16
# Ho                13
# Methylation       13
# PSM               13
# BRD               11
# Acetalax           4
# dtype: int64

# %% [markdown]
# # Merge label to main table on NSC

# %%
base_label = base.merge(class_nsc, on='NSC')
base_label
# Out:
#             NSC  drug_response                                    cell_line  \
# 0             1      -0.519867                                  786O_KIDNEY
# 1             1      -0.918047                         HT29_LARGE_INTESTINE
# 2             1      -0.802747                                 NCIH322_LUNG
# 3             1       0.325208     SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 4             1       1.934731                                  T47D_BREAST
# ...         ...            ...                                          ...
# 1209388  701664       0.430721  RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 1209389  701664      -3.869090                        SW620_LARGE_INTESTINE
# 1209390  701664       2.979306     MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 1209391  701664      -0.123051                                 NCIH460_LUNG
# 1209392  701664      -2.302806                                 CAKI1_KIDNEY
#
#         MECHANISM
# 0           Other
# 1           Other
# 2           Other
# 3           Other
# 4           Other
# ...           ...
# 1209388     Other
# 1209389     Other
# 1209390     Other
# 1209391     Other
# 1209392     Other
#
# [1209393 rows x 4 columns]

# %% [markdown]
# # Merge SMILES to main table on NSC

# %%
smiles = pd.read_csv('../data/nsc_cid_smiles.csv')[['NSC', 'SMILES']].drop_duplicates()
base_smiles = base_label.merge(smiles, on='NSC').drop('NSC', axis=1)
base_smiles
# Out:
#         drug_response                                    cell_line MECHANISM  \
# 0            0.521200                                  786O_KIDNEY     Other
# 1           -0.941890                         HT29_LARGE_INTESTINE     Other
# 2           -0.786423                                 NCIH322_LUNG     Other
# 3            0.621871     SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Other
# 4            1.509397                                  T47D_BREAST     Other
# ...               ...                                          ...       ...
# 877939       0.430721  RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Other
# 877940      -3.869090                        SW620_LARGE_INTESTINE     Other
# 877941       2.979306     MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Other
# 877942      -0.123051                                 NCIH460_LUNG     Other
# 877943      -2.302806                                 CAKI1_KIDNEY     Other
#
#                                                    SMILES
# 0                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 1                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 2                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 3                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 4                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# ...                                                   ...
# 877939  CC(C)(C)C1=CC(=CC(=C1O)C(C)(C)C)C2=CSC(=NC3=CC...
# 877940  CC(C)(C)C1=CC(=CC(=C1O)C(C)(C)C)C2=CSC(=NC3=CC...
# 877941  CC(C)(C)C1=CC(=CC(=C1O)C(C)(C)C)C2=CSC(=NC3=CC...
# 877942  CC(C)(C)C1=CC(=CC(=C1O)C(C)(C)C)C2=CSC(=NC3=CC...
# 877943  CC(C)(C)C1=CC(=CC(=C1O)C(C)(C)C)C2=CSC(=NC3=CC...
#
# [877944 rows x 4 columns]

# %%
base_smiles.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other        858874
# DNA           11820
# Kinase         1988
# HDAC           1709
# TUBB           1679
# Ho              615
# Apoptosis       610
# HSP90           274
# PSM             212
# Acetalax        163
# dtype: int64

# %%
set(base_smiles['MECHANISM'])
# Out:
# {'Acetalax',
#  'Apoptosis',
#  'DNA',
#  'HDAC',
#  'HSP90',
#  'Ho',
#  'Kinase',
#  'Other',
#  'PSM',
#  'TUBB'}

# %% [markdown]
# # Select DNA

# %%
df_dna = base_smiles[base_smiles['MECHANISM'] == 'DNA'].reset_index(drop=True)[['cell_line', 'SMILES', 'drug_response']]

# %% [markdown]
# # This has 11820 datapoints

# %%
df_dna.drop_duplicates()
# Out:
#                                       cell_line  \
# 0                                   786O_KIDNEY
# 1                          HT29_LARGE_INTESTINE
# 2                                  NCIH322_LUNG
# 3      SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 4                                   T47D_BREAST
# ...                                         ...
# 11815                     SW620_LARGE_INTESTINE
# 11816  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 11817                              IGROV1_OVARY
# 11818                              NCIH460_LUNG
# 11819                              CAKI1_KIDNEY
#
#                                                   SMILES  drug_response
# 0      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.682664
# 1      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.616085
# 2      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -0.356232
# 3      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.645528
# 4      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -1.156158
# ...                                                  ...            ...
# 11815            COC1=NC(=NC2=C1N=CN2C3C(C(C(O3)CO)O)O)N      -0.174699
# 11816            COC1=NC(=NC2=C1N=CN2C3C(C(C(O3)CO)O)O)N       2.612786
# 11817            COC1=NC(=NC2=C1N=CN2C3C(C(C(O3)CO)O)O)N      -0.174699
# 11818            COC1=NC(=NC2=C1N=CN2C3C(C(C(O3)CO)O)O)N      -0.174699
# 11819            COC1=NC(=NC2=C1N=CN2C3C(C(C(O3)CO)O)O)N      -0.174699
#
# [11820 rows x 3 columns]

# %% [markdown]
# # 55 cell lines and 214 drugs

# %%
len(set(df_dna['cell_line']))
# Out:
# 55

# %%
len(set(df_dna['SMILES']))
# Out:
# 214

# %%
pd.DataFrame(df_dna['cell_line'].value_counts())
# Out:
#                                              cell_line
# U251MG_CENTRAL_NERVOUS_SYSTEM                      222
# KM12_LARGE_INTESTINE                               222
# A549_LUNG                                          222
# UACC257_SKIN                                       222
# UACC62_SKIN                                        222
# SKMEL28_SKIN                                       222
# EKVX_LUNG                                          222
# OVCAR5_OVARY                                       222
# OVCAR4_OVARY                                       222
# OVCAR8_OVARY                                       222
# SF295_CENTRAL_NERVOUS_SYSTEM                       222
# SF268_CENTRAL_NERVOUS_SYSTEM                       221
# NCIH23_LUNG                                        221
# HCT116_LARGE_INTESTINE                             221
# HCT15_LARGE_INTESTINE                              221
# SF539_CENTRAL_NERVOUS_SYSTEM                       221
# SW620_LARGE_INTESTINE                              221
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           221
# NCIH460_LUNG                                       221
# HT29_LARGE_INTESTINE                               221
# CAKI1_KIDNEY                                       221
# NCIH522_LUNG                                       220
# SNB75_CENTRAL_NERVOUS_SYSTEM                       220
# COLO205_LARGE_INTESTINE                            220
# NCIH322_LUNG                                       220
# SN12C_KIDNEY                                       220
# LOXIMVI_SKIN                                       220
# MALME3M_SKIN                                       220
# NCIH226_LUNG                                       219
# IGROV1_OVARY                                       219
# HOP62_LUNG                                         219
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        218
# HCC2998_LARGE_INTESTINE                            218
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            218
# RXF393_KIDNEY                                      218
# SKMEL2_SKIN                                        218
# SKMEL5_SKIN                                        217
# HOP92_LUNG                                         217
# A498_KIDNEY                                        216
# SKOV3_OVARY                                        216
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         215
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            213
# M14_SKIN                                           209
# TK10_KIDNEY                                        209
# ACHN_KIDNEY                                        208
# MCF7_BREAST                                        207
# 786O_KIDNEY                                        204
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           197
# PC3_PROSTATE                                       196
# MDAMB435S_SKIN                                     195
# MDAMB231_BREAST                                    195
# DU145_PROSTATE                                     195
# HS578T_BREAST                                      194
# T47D_BREAST                                        191
# BT549_BREAST                                       187

# %%
pd.DataFrame(df_dna['SMILES'].value_counts())
# Out:
#                                                     SMILES
# C1C(C(OC1N2C=NC3=C2NC(=NC3=S)N)CO)O                    110
# C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)O                     110
# CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=C(C=CC(=C5CN(C)...     110
# CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C(...     110
# COC1=C(C=CC(=C1)NS(=O)(=O)C)NC2=C3C=CC=CC3=NC4=...     110
# ...                                                    ...
# C1CN2C(=CC=N2)N1                                        43
# C1CC(OC1CO)N2C=CC(=NC2=O)N                              42
# C1=CC=C(C(=C1)C(=O)NCCCC(C(=O)O)NC(=O)C2=CC=C(C...      41
# C1CCC2(CC1)C(=O)N(C(=O)N2)CCN(CCCl)CCCl                 40
# C1=CC=C(C(=C1)C(C2=CC=C(C=C2)Cl)C(Cl)Cl)Cl              39
#
# [214 rows x 1 columns]

# %%
indexes = list(df_dna.index)
rd.Random(42).shuffle(indexes)

# %%
test = indexes[round(len(indexes)*0.8):]
tmp = indexes[:round(len(indexes)*0.8)]
val = tmp[:len(test)]
train = tmp[len(test):]

# %%
train = df_dna.iloc[train]
test = df_dna.iloc[test]
val = df_dna.iloc[val]

# %%
print('train: ' + str(train.shape))
print('val: ' + str(val.shape))
print('test: ' + str(test.shape))
# Out:
# train: (7092, 3)
# val: (2364, 3)
# test: (2364, 3)

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train['cell_line'].value_counts()), 
        pd.DataFrame(val['cell_line'].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test['cell_line'].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
df
# Out:
#                                              train   val  test
# SKMEL5_SKIN                                    147    34    36
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    144    35    39
# LOXIMVI_SKIN                                   142    37    41
# CAKI1_KIDNEY                                   141    40    40
# MALME3M_SKIN                                   141    44    35
# UACC257_SKIN                                   140    43    39
# IGROV1_OVARY                                   137    38    44
# HCT116_LARGE_INTESTINE                         137    39    45
# EKVX_LUNG                                      137    45    40
# A549_LUNG                                      136    43    43
# SF539_CENTRAL_NERVOUS_SYSTEM                   136    45    40
# NCIH322_LUNG                                   136    37    47
# NCIH522_LUNG                                   135    47    38
# SF295_CENTRAL_NERVOUS_SYSTEM                   135    36    51
# HCC2998_LARGE_INTESTINE                        135    49    34
# OVCAR5_OVARY                                   135    42    45
# HOP92_LUNG                                     134    44    39
# SKMEL2_SKIN                                    134    41    43
# A498_KIDNEY                                    133    26    57
# ACHN_KIDNEY                                    132    42    34
# OVCAR4_OVARY                                   132    49    41
# SW620_LARGE_INTESTINE                          132    48    41
# SF268_CENTRAL_NERVOUS_SYSTEM                   132    44    45
# MCF7_BREAST                                    131    39    37
# HCT15_LARGE_INTESTINE                          131    49    41
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        131    49    38
# HT29_LARGE_INTESTINE                           131    42    48
# M14_SKIN                                       131    45    33
# TK10_KIDNEY                                    131    44    34
# SNB75_CENTRAL_NERVOUS_SYSTEM                   130    47    43
# U251MG_CENTRAL_NERVOUS_SYSTEM                  130    48    44
# COLO205_LARGE_INTESTINE                        129    41    50
# SKMEL28_SKIN                                   128    50    44
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       128    28    41
# OVCAR8_OVARY                                   127    47    48
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        127    40    46
# KM12_LARGE_INTESTINE                           127    45    50
# SN12C_KIDNEY                                   127    43    50
# MDAMB231_BREAST                                125    36    34
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     124    36    55
# HOP62_LUNG                                     124    52    43
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       123    62    36
# BT549_BREAST                                   121    24    42
# NCIH226_LUNG                                   121    45    53
# HS578T_BREAST                                  120    42    32
# UACC62_SKIN                                    120    51    51
# PC3_PROSTATE                                   119    48    29
# NCIH23_LUNG                                    118    47    56
# T47D_BREAST                                    117    39    35
# RXF393_KIDNEY                                  117    47    54
# SKOV3_OVARY                                    115    45    56
# MDAMB435S_SKIN                                 115    42    38
# NCIH460_LUNG                                   112    49    60
# DU145_PROSTATE                                 110    41    44
# 786O_KIDNEY                                    109    53    42
# total                                         7092  2364  2364

# %%
test.to_csv(
    '../DrugCell/data_rcellminer/test_DNA.txt', sep='\t', 
    header=None, index=None
)

val.to_csv(
    '../DrugCell/data_rcellminer/val_DNA.txt', sep='\t', 
    header=None, index=None
)

train.to_csv(
    '../DrugCell/data_rcellminer/train_DNA.txt', sep='\t', 
    header=None, index=None
)
