# %%
import pandas as pd
import numpy as np
import random as rd

from urllib.request import HTTPError
from tqdm import tqdm
from joblib import Parallel, delayed

# %% [markdown]
# # Read nci60byCell Line Table
#  Indexes are NSC and columns are Cell Lines' name

# %%
nci60Act = pd.read_csv("../data/nci60Act_ccle.csv", index_col=0)
cell2ind = list(pd.read_table("../DrugCell/data/cell2ind.txt", header=None)[1])
nci60Act = nci60Act[list(set(cell2ind) & set(nci60Act.columns))]
nci60Act
# Out:
#         CAKI1_KIDNEY  SNB75_CENTRAL_NERVOUS_SYSTEM  OVCAR8_OVARY  T47D_BREAST  \
# 1          -0.269717                     -0.175915     -0.413599     1.934731
# 17          0.717851                      0.330808     -0.572734     1.509397
# 89          0.743888                     -0.216723      0.185498          NaN
# 185         1.675353                     -1.125208      0.095648          NaN
# 295        -0.264586                     -0.264586      3.362653    -0.264586
# ...              ...                           ...           ...          ...
# 900911     -0.167151                     -0.167151     -0.167151    -0.167151
# 900922     -0.169786                     -0.169786     -0.169786    -0.169786
# 900964     -0.158754                     -0.158754     -0.158754    -0.158754
# 900974     -0.132453                     -0.132453     -0.132453    -0.132453
# 921923     -0.559582                           NaN     -0.443540          NaN
#
#         NCIH23_LUNG  M14_SKIN  HT29_LARGE_INTESTINE  A549_LUNG  \
# 1         -0.600872 -0.508668             -0.918047  -0.826223
# 17        -0.925414 -0.941890             -0.941890  -0.941890
# 89        -0.312738  0.430283             -0.487137  -0.433001
# 185        0.170420 -0.533247             -0.283713   0.500858
# 295       -0.264586 -0.264586             -0.264586  -0.264586
# ...             ...       ...                   ...        ...
# 900911    -0.167151 -0.167151             -0.167151  -0.167151
# 900922    -0.169786 -0.169786             -0.169786        NaN
# 900964    -0.158754 -0.158754             -0.158754  -0.158754
# 900974    -0.132453 -0.132453             -0.132453  -0.132453
# 921923    -0.030625 -0.388650             -0.560096  -0.453344
#
#         COLO205_LARGE_INTESTINE  OVCAR4_OVARY  ...  \
# 1                      0.008989      2.081990  ...
# 17                    -0.041714      0.891796  ...
# 89                     0.152000      0.012308  ...
# 185                    0.174485      0.487376  ...
# 295                   -0.264586     -0.264586  ...
# ...                         ...           ...  ...
# 900911                -0.167151     -0.167151  ...
# 900922                -0.169786     -0.169786  ...
# 900964                      NaN     -0.158754  ...
# 900974                -0.132453     -0.132453  ...
# 921923                -0.213616     -0.229151  ...
#
#         SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 1                                       0.325208
# 17                                      0.621871
# 89                                     -0.222065
# 185                                          NaN
# 295                                     2.919066
# ...                                          ...
# 900911                                 -0.167151
# 900922                                 -0.169786
# 900964                                 -0.158754
# 900974                                 -0.132453
# 921923                                  1.350827
#
#         HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  SN12C_KIDNEY  \
# 1                                      1.439737     -0.390689
# 17                                     1.792720     -0.315533
# 89                                     1.054381     -0.184805
# 185                                    0.381192      1.391604
# 295                                   -0.264586     -0.264586
# ...                                         ...           ...
# 900911                                      NaN     -0.167151
# 900922                                -0.169786     -0.169786
# 900964                                -0.158754     -0.158754
# 900974                                -0.132453     -0.132453
# 921923                                 1.352788      0.705388
#
#         HCT15_LARGE_INTESTINE  IGROV1_OVARY  SF539_CENTRAL_NERVOUS_SYSTEM  \
# 1                   -0.082824      0.149074                     -0.380720
# 17                  -0.630920      1.353076                      1.140166
# 89                   0.236371     -0.181827                     -0.165433
# 185                 -0.059621     -0.852569                      0.230402
# 295                 -0.264586     -0.264586                     -0.264586
# ...                       ...           ...                           ...
# 900911              -0.167151     -0.167151                     -0.167151
# 900922              -0.169786     -0.169786                     -0.169786
# 900964              -0.158754     -0.158754                     -0.158754
# 900974              -0.132453     -0.132453                     -0.132453
# 921923              -0.368297     -0.251762                     -0.268661
#
#         OVCAR5_OVARY  TK10_KIDNEY  HCT116_LARGE_INTESTINE  HOP92_LUNG
# 1          -0.593334    -0.379420                0.732038    2.110059
# 17         -0.422527    -0.761559               -0.941890   -0.078754
# 89         -0.145313    -0.101929                0.347687   -0.068839
# 185        -0.853432    -0.904724                     NaN   -0.038789
# 295        -0.264586    -0.264586               -0.264586   -0.264586
# ...              ...          ...                     ...         ...
# 900911     -0.167151    -0.167151               -0.167151         NaN
# 900922     -0.169786    -0.169786               -0.169786   -0.169786
# 900964     -0.158754    -0.158754               -0.158754   -0.158754
# 900974     -0.132453    -0.132453               -0.132453   -0.132453
# 921923     -1.152361     1.538064               -0.194546   -0.238120
#
# [24047 rows x 55 columns]

# %% [markdown]
# # Create train data table format

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = nci60Act[i].reset_index().dropna()
    tmp.columns = ['NSC', 'drug_response']
    tmp['cell_line'] = [i]*len(tmp)
    base = pd.concat([
        base,
        tmp
    ])
base = base.reset_index(drop=True)

# %%
base
# Out:
#             NSC  drug_response     cell_line
# 0             1      -0.269717  CAKI1_KIDNEY
# 1            17       0.717851  CAKI1_KIDNEY
# 2            89       0.743888  CAKI1_KIDNEY
# 3           185       1.675353  CAKI1_KIDNEY
# 4           295      -0.264586  CAKI1_KIDNEY
# ...         ...            ...           ...
# 1219790  900909      -0.189827    HOP92_LUNG
# 1219791  900922      -0.169786    HOP92_LUNG
# 1219792  900964      -0.158754    HOP92_LUNG
# 1219793  900974      -0.132453    HOP92_LUNG
# 1219794  921923      -0.238120    HOP92_LUNG
#
# [1219795 rows x 3 columns]

# %% [markdown]
# # Read class label

# %%
class_nsc = pd.read_csv('../DrugCell/data_rcellminer/class_by_nsc.csv')
class_nsc
# Out:
#           NSC    MECHANISM
# 0      762419        Other
# 1      719239        Other
# 2      777573        Other
# 3      774651        Other
# 4      765776        Other
# ...       ...          ...
# 23846  810341  Methylation
# 23847  808507  Methylation
# 23848  785299  Methylation
# 23849  790865  Methylation
# 23850  780404  Methylation
#
# [23851 rows x 2 columns]

# %% [markdown]
# # Unique number of cell lines for each class
# There are 274 cell lines of DNA class

# %%
class_nsc.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other          22895
# Kinase           483
# DNA              274
# HDAC              46
# TUBB              45
# Apoptosis         38
# HSP90             16
# Ho                13
# Methylation       13
# PSM               13
# BRD               11
# Acetalax           4
# dtype: int64

# %% [markdown]
# # Merge label to main table on NSC

# %%
base_label = base.merge(class_nsc, on='NSC')
base_label
# Out:
#             NSC  drug_response                     cell_line MECHANISM
# 0             1      -0.269717                  CAKI1_KIDNEY     Other
# 1             1      -0.175915  SNB75_CENTRAL_NERVOUS_SYSTEM     Other
# 2             1      -0.413599                  OVCAR8_OVARY     Other
# 3             1       1.934731                   T47D_BREAST     Other
# 4             1      -0.600872                   NCIH23_LUNG     Other
# ...         ...            ...                           ...       ...
# 1209388  709521      -0.462382  SF539_CENTRAL_NERVOUS_SYSTEM     Other
# 1209389  709521      -1.286388                  OVCAR5_OVARY     Other
# 1209390  709521      -0.237036                   TK10_KIDNEY     Other
# 1209391  709521       0.356641        HCT116_LARGE_INTESTINE     Other
# 1209392  709521      -1.861452                    HOP92_LUNG     Other
#
# [1209393 rows x 4 columns]

# %% [markdown]
# # Get SMILES from pubchem id

# %%
def get_SMILES_from_pubchemID(pubchem_id):
    """
    Get the SMILES from pubchem_id using PubChem API

    Parameters
    ----------

    pubchem_id : pd.DataFrame

    Returns
    -------

    df : pd.DataFrame

    """

    df = pd.DataFrame()
    for i in tqdm(
        list(range(500, pubchem_id.shape[0], 500)) + [pubchem_id.shape[0]]
    ):
        cid = ""
        for j in pubchem_id["CID"][i - 500 : i]:
            cid = str(j) + "," + cid

        try:
            df = pd.concat(
                [
                    pd.read_csv(
                        "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/"
                        + cid
                        + "/property/CanonicalSMILES/CSV"
                    ),
                    df,
                ]
            )
        except HTTPError as e:
            # if we got error, devided by more small number to get where we got the error.
            # Not sure why I didn't get error again though...
            for i in np.array_split(np.array(cid.split(",")), 2):
                t = ""
                for l in i:
                    t += l + ","
                try:
                    df = pd.concat(
                        [
                            pd.read_csv(
                                "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/"
                                + t
                                + "/property/CanonicalSMILES/CSV"
                            ),
                            df,
                        ]
                    )
                except HTTPError as e:
                    if e.code == 403:
                        print("error")
    df = (
        df.drop_duplicates("CanonicalSMILES")
        .sort_values("CID")
        .reset_index(drop=True)
    )
    df = pubchem_id.reset_index().merge(df, on="CID")[
        ["index", "CanonicalSMILES"]
    ]
    df.columns = ["NSC", "SMILES"]

    return df

# %%
pubchem_id = pd.read_csv('../data/nci60PubChemID.csv', index_col=0).dropna()
pubchem_id = pubchem_id.sort_values('PUBCHEM_ID')
pubchem_id.columns = ['CID']

# %%
df = get_SMILES_from_pubchemID(pubchem_id)
# Out:
# 100%|██████████| 34/34 [00:10<00:00,  3.33it/s]

# %% [markdown]
# # Merge SMILES to main table on NSC

# %%
base_smiles = base_label.merge(df, on='NSC').drop('NSC', axis=1)
base_smiles
# Out:
#         drug_response                     cell_line MECHANISM  \
# 0            0.717851                  CAKI1_KIDNEY     Other
# 1            0.330808  SNB75_CENTRAL_NERVOUS_SYSTEM     Other
# 2           -0.572734                  OVCAR8_OVARY     Other
# 3            1.509397                   T47D_BREAST     Other
# 4           -0.925414                   NCIH23_LUNG     Other
# ...               ...                           ...       ...
# 822755      -0.462382  SF539_CENTRAL_NERVOUS_SYSTEM     Other
# 822756      -1.286388                  OVCAR5_OVARY     Other
# 822757      -0.237036                   TK10_KIDNEY     Other
# 822758       0.356641        HCT116_LARGE_INTESTINE     Other
# 822759      -1.861452                    HOP92_LUNG     Other
#
#                                                    SMILES
# 0                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 1                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 2                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 3                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 4                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# ...                                                   ...
# 822755  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
# 822756  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
# 822757  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
# 822758  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
# 822759  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
#
# [822760 rows x 4 columns]

# %%
base_smiles
# Out:
#         drug_response                     cell_line MECHANISM  \
# 0            0.717851                  CAKI1_KIDNEY     Other
# 1            0.330808  SNB75_CENTRAL_NERVOUS_SYSTEM     Other
# 2           -0.572734                  OVCAR8_OVARY     Other
# 3            1.509397                   T47D_BREAST     Other
# 4           -0.925414                   NCIH23_LUNG     Other
# ...               ...                           ...       ...
# 822755      -0.462382  SF539_CENTRAL_NERVOUS_SYSTEM     Other
# 822756      -1.286388                  OVCAR5_OVARY     Other
# 822757      -0.237036                   TK10_KIDNEY     Other
# 822758       0.356641        HCT116_LARGE_INTESTINE     Other
# 822759      -1.861452                    HOP92_LUNG     Other
#
#                                                    SMILES
# 0                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 1                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 2                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 3                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# 4                        CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N
# ...                                                   ...
# 822755  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
# 822756  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
# 822757  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
# 822758  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
# 822759  COC1=CC=C(C=C1)C2=NN=C3C(=NC4=CC=CC=C4N3C2)C5=...
#
# [822760 rows x 4 columns]

# %%
base_smiles.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other        811190
# DNA            6535
# HDAC           1598
# Kinase         1332
# TUBB           1272
# Ho              363
# Apoptosis       313
# PSM             102
# Acetalax         55
# dtype: int64

# %%
set(base_smiles['MECHANISM'])
# Out:
# {'Acetalax',
#  'Apoptosis',
#  'DNA',
#  'HDAC',
#  'Ho',
#  'Kinase',
#  'Other',
#  'PSM',
#  'TUBB'}

# %%
base_smiles[
    (base_smiles['MECHANISM'] == 'DNA') |
    (base_smiles['MECHANISM'] == 'HDAC') |
    (base_smiles['MECHANISM'] == 'Kinase') |
    (base_smiles['MECHANISM'] == 'TUBB')
]
# Out:
#         drug_response                     cell_line MECHANISM  \
# 364          0.541612                  CAKI1_KIDNEY       DNA
# 365         -1.460314  SNB75_CENTRAL_NERVOUS_SYSTEM       DNA
# 366          0.644535                  OVCAR8_OVARY       DNA
# 367         -1.156158                   T47D_BREAST       DNA
# 368          0.510736                   NCIH23_LUNG       DNA
# ...               ...                           ...       ...
# 821679       0.014236  SF539_CENTRAL_NERVOUS_SYSTEM      HDAC
# 821680      -0.678015                  OVCAR5_OVARY      HDAC
# 821681       0.109471                   TK10_KIDNEY      HDAC
# 821682       0.497262        HCT116_LARGE_INTESTINE      HDAC
# 821683       0.463246                    HOP92_LUNG      HDAC
#
#                                                    SMILES
# 364     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 365     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 366     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 367     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 368     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# ...                                                   ...
# 821679  C=C(CN1CCC2=C(C1)NC3=CC=CC=C23)C4=CC=C(C=C4)C(...
# 821680  C=C(CN1CCC2=C(C1)NC3=CC=CC=C23)C4=CC=C(C=C4)C(...
# 821681  C=C(CN1CCC2=C(C1)NC3=CC=CC=C23)C4=CC=C(C=C4)C(...
# 821682  C=C(CN1CCC2=C(C1)NC3=CC=CC=C23)C4=CC=C(C=C4)C(...
# 821683  C=C(CN1CCC2=C(C1)NC3=CC=CC=C23)C4=CC=C(C=C4)C(...
#
# [10737 rows x 4 columns]

# %% [markdown]
# # Select DNA

# %%
df_dna = base_smiles[base_smiles['MECHANISM'] == 'DNA'].reset_index(drop=True)[['cell_line', 'SMILES', 'drug_response']]

# %% [markdown]
# # This has 6779 datapoints

# %%
df_dna
# Out:
#                          cell_line  \
# 0                     CAKI1_KIDNEY
# 1     SNB75_CENTRAL_NERVOUS_SYSTEM
# 2                     OVCAR8_OVARY
# 3                      T47D_BREAST
# 4                      NCIH23_LUNG
# ...                            ...
# 6530  SF539_CENTRAL_NERVOUS_SYSTEM
# 6531                  OVCAR5_OVARY
# 6532                   TK10_KIDNEY
# 6533        HCT116_LARGE_INTESTINE
# 6534                    HOP92_LUNG
#
#                                                  SMILES  drug_response
# 0     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.541612
# 1     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -1.460314
# 2     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.644535
# 3     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -1.156158
# 4     CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.510736
# ...                                                 ...            ...
# 6530  CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C3=C2)N=C5C=C(C(...       1.107856
# 6531  CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C3=C2)N=C5C=C(C(...      -1.271092
# 6532  CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C3=C2)N=C5C=C(C(...      -1.271092
# 6533  CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C3=C2)N=C5C=C(C(...      -0.020776
# 6534  CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C3=C2)N=C5C=C(C(...      -1.271092
#
# [6535 rows x 3 columns]

# %% [markdown]
# # 57 cell lines and 122 drugs

# %%
len(set(df_dna['cell_line']))
# Out:
# 55

# %%
len(set(df_dna['SMILES']))
# Out:
# 122

# %%
pd.DataFrame(df_dna['cell_line'].value_counts())
# Out:
#                                              cell_line
# SF539_CENTRAL_NERVOUS_SYSTEM                       122
# UACC257_SKIN                                       122
# KM12_LARGE_INTESTINE                               122
# NCIH460_LUNG                                       122
# SN12C_KIDNEY                                       122
# U251MG_CENTRAL_NERVOUS_SYSTEM                      122
# UACC62_SKIN                                        122
# SF295_CENTRAL_NERVOUS_SYSTEM                       122
# SKMEL28_SKIN                                       122
# SF268_CENTRAL_NERVOUS_SYSTEM                       122
# OVCAR4_OVARY                                       122
# EKVX_LUNG                                          122
# A549_LUNG                                          122
# HT29_LARGE_INTESTINE                               122
# OVCAR5_OVARY                                       122
# HCT116_LARGE_INTESTINE                             122
# OVCAR8_OVARY                                       122
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           121
# MALME3M_SKIN                                       121
# SW620_LARGE_INTESTINE                              121
# CAKI1_KIDNEY                                       121
# HCT15_LARGE_INTESTINE                              121
# A498_KIDNEY                                        121
# LOXIMVI_SKIN                                       121
# IGROV1_OVARY                                       121
# NCIH522_LUNG                                       121
# COLO205_LARGE_INTESTINE                            121
# NCIH23_LUNG                                        121
# HCC2998_LARGE_INTESTINE                            120
# NCIH322_LUNG                                       120
# SNB75_CENTRAL_NERVOUS_SYSTEM                       120
# NCIH226_LUNG                                       120
# HOP62_LUNG                                         120
# SKMEL5_SKIN                                        120
# RXF393_KIDNEY                                      119
# TK10_KIDNEY                                        119
# M14_SKIN                                           119
# ACHN_KIDNEY                                        119
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        119
# SKMEL2_SKIN                                        119
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            119
# HOP92_LUNG                                         118
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         117
# 786O_KIDNEY                                        116
# MCF7_BREAST                                        116
# SKOV3_OVARY                                        116
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            114
# PC3_PROSTATE                                       112
# MDAMB435S_SKIN                                     112
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           111
# DU145_PROSTATE                                     111
# MDAMB231_BREAST                                    110
# HS578T_BREAST                                      110
# T47D_BREAST                                        109
# BT549_BREAST                                       105

# %%
pd.DataFrame(df_dna['SMILES'].value_counts())
# Out:
#                                                     SMILES
# CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C(...      55
# CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C5=CC=CC=C5N=C4C3...      55
# CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C5=CC=CC=C5N=C4C3...      55
# CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3=...      55
# CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C5=CC=CC=C5N=C4C3...      55
# ...                                                    ...
# CC1=C(C=CC(=C1)N(CCOS(=O)(=O)C)CCOS(=O)(=O)C)C=O        46
# CCC1(C2=C(COC1=O)C(=O)N3CC4=C(C3=C2)N=C5C=C(C(=...      43
# C1C(ON=C1Cl)C(C(=O)O)N                                  43
# CC1=C2C=C[N+](=CC2=C(C3=C1NC4=CC=CC=C43)C)C.[I-]        43
# C1CCC2(CC1)C(=O)N(C(=O)N2)CCN(CCCl)CCCl                 40
#
# [122 rows x 1 columns]

# %%
indexes = list(df_dna.index)
rd.Random(42).shuffle(indexes)

# %%
test = indexes[round(len(indexes)*0.8):]
tmp = indexes[:round(len(indexes)*0.8)]
val = tmp[:len(test)]
train = tmp[len(test):]

# %%
train = df_dna.iloc[train]
test = df_dna.iloc[test]
val = df_dna.iloc[val]

# %%
print('train: ' + str(train.shape))
print('val: ' + str(val.shape))
print('test: ' + str(test.shape))
# Out:
# train: (3921, 3)
# val: (1307, 3)
# test: (1307, 3)

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train['cell_line'].value_counts()), 
        pd.DataFrame(val['cell_line'].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test['cell_line'].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
df
# Out:
#                                              train   val  test
# OVCAR8_OVARY                                    87    13    22
# IGROV1_OVARY                                    80    23    18
# CAKI1_KIDNEY                                    80    18    23
# HCC2998_LARGE_INTESTINE                         80    17    23
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        80    13    28
# UACC62_SKIN                                     79    21    22
# NCIH460_LUNG                                    79    21    22
# A549_LUNG                                       78    15    29
# SF268_CENTRAL_NERVOUS_SYSTEM                    76    27    19
# SF295_CENTRAL_NERVOUS_SYSTEM                    76    27    19
# UACC257_SKIN                                    76    17    29
# NCIH322_LUNG                                    75    29    16
# OVCAR5_OVARY                                    75    23    24
# HCT116_LARGE_INTESTINE                          75    23    24
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     75    21    23
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         74    21    19
# HOP92_LUNG                                      74    19    25
# MALME3M_SKIN                                    74    27    20
# HS578T_BREAST                                   74    15    21
# SNB75_CENTRAL_NERVOUS_SYSTEM                    73    22    25
# HCT15_LARGE_INTESTINE                           73    24    24
# M14_SKIN                                        73    25    21
# EKVX_LUNG                                       73    28    21
# SKOV3_OVARY                                     73    18    25
# RXF393_KIDNEY                                   72    26    21
# SKMEL5_SKIN                                     72    26    22
# SF539_CENTRAL_NERVOUS_SYSTEM                    72    27    23
# HOP62_LUNG                                      72    16    32
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      71    17    29
# MCF7_BREAST                                     71    28    17
# 786O_KIDNEY                                     71    19    26
# SW620_LARGE_INTESTINE                           70    28    23
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         69    29    21
# PC3_PROSTATE                                    69    28    15
# NCIH226_LUNG                                    69    27    24
# SKMEL2_SKIN                                     69    21    29
# LOXIMVI_SKIN                                    69    29    23
# MDAMB435S_SKIN                                  68    19    25
# KM12_LARGE_INTESTINE                            68    28    26
# A498_KIDNEY                                     68    27    26
# COLO205_LARGE_INTESTINE                         67    23    31
# U251MG_CENTRAL_NERVOUS_SYSTEM                   67    28    27
# NCIH23_LUNG                                     67    25    29
# MDAMB231_BREAST                                 66    19    25
# NCIH522_LUNG                                    66    25    30
# HT29_LARGE_INTESTINE                            66    32    24
# ACHN_KIDNEY                                     66    31    22
# SKMEL28_SKIN                                    65    32    25
# TK10_KIDNEY                                     65    29    25
# DU145_PROSTATE                                  65    26    20
# BT549_BREAST                                    64    20    21
# SN12C_KIDNEY                                    64    30    28
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        62    27    22
# T47D_BREAST                                     60    24    25
# OVCAR4_OVARY                                    59    34    29
# total                                         3921  1307  1307

# %%
test.to_csv(
    '../DrugCell/data_rcellminer/test_DNA.txt', sep='\t', 
    header=None, index=None
)

val.to_csv(
    '../DrugCell/data_rcellminer/val_DNA.txt', sep='\t', 
    header=None, index=None
)

train.to_csv(
    '../DrugCell/data_rcellminer/train_DNA.txt', sep='\t', 
    header=None, index=None
)
