# %%
import pandas as pd
import numpy as np
import random as rd

from urllib.request import HTTPError
from tqdm import tqdm
from joblib import Parallel, delayed

# %% [markdown]
# # Read nci60byCell Line Table
#  Indexes are NSC and columns are Cell Lines' name

# %%
nci60Act = pd.read_csv("../data/nci60Act_ccle.csv", index_col=0)
cell2ind = list(pd.read_table("../DrugCell/data/cell2ind.txt", header=None)[1])
nci60Act = nci60Act[list(set(cell2ind) & set(nci60Act.columns))]
nci60Act
# Out:
#         SF295_CENTRAL_NERVOUS_SYSTEM  SN12C_KIDNEY  HOP92_LUNG  NCIH522_LUNG  \
# 1                          -0.719253     -0.390689    2.110059      1.914094
# 17                          0.424922     -0.315533   -0.078754      1.832493
# 89                         -1.429903     -0.184805   -0.068839      5.026869
# 185                              NaN      1.391604   -0.038789           NaN
# 295                        -0.264586     -0.264586   -0.264586     -0.264586
# ...                              ...           ...         ...           ...
# 900911                     -0.167151     -0.167151         NaN           NaN
# 900922                     -0.169786     -0.169786   -0.169786     -0.169786
# 900964                     -0.158754     -0.158754   -0.158754     -0.158754
# 900974                     -0.132453     -0.132453   -0.132453     -0.132453
# 921923                     -0.961518      0.705388   -0.238120      0.682694
#
#         SF268_CENTRAL_NERVOUS_SYSTEM  SF539_CENTRAL_NERVOUS_SYSTEM  \
# 1                          -0.357577                     -0.380720
# 17                          0.335572                      1.140166
# 89                         -0.184194                     -0.165433
# 185                         0.539343                      0.230402
# 295                        -0.264586                     -0.264586
# ...                              ...                           ...
# 900911                     -0.167151                     -0.167151
# 900922                     -0.169786                     -0.169786
# 900964                     -0.158754                     -0.158754
# 900974                     -0.132453                     -0.132453
# 921923                     -0.126943                     -0.268661
#
#         NCIH226_LUNG  SNB75_CENTRAL_NERVOUS_SYSTEM  TK10_KIDNEY  \
# 1          -1.164555                     -0.175915    -0.379420
# 17          0.100266                      0.330808    -0.761559
# 89         -0.605885                     -0.216723    -0.101929
# 185        -3.502638                     -1.125208    -0.904724
# 295        -0.264586                     -0.264586    -0.264586
# ...              ...                           ...          ...
# 900911     -0.167151                     -0.167151    -0.167151
# 900922     -0.169786                     -0.169786    -0.169786
# 900964     -0.158754                     -0.158754    -0.158754
# 900974     -0.132453                     -0.132453    -0.132453
# 921923     -0.246742                           NaN     1.538064
#
#         U251MG_CENTRAL_NERVOUS_SYSTEM  ...  \
# 1                           -0.266183  ...
# 17                          -0.843055  ...
# 89                          -0.093513  ...
# 185                         -0.171509  ...
# 295                         -0.264586  ...
# ...                               ...  ...
# 900911                            NaN  ...
# 900922                      -0.169786  ...
# 900964                      -0.158754  ...
# 900974                      -0.132453  ...
# 921923                       0.353673  ...
#
#         SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  IGROV1_OVARY  MCF7_BREAST  \
# 1                                       0.325208      0.149074    -0.271314
# 17                                      0.621871      1.353076    -0.354110
# 89                                     -0.222065     -0.181827          NaN
# 185                                          NaN     -0.852569          NaN
# 295                                     2.919066     -0.264586    -0.264586
# ...                                          ...           ...          ...
# 900911                                 -0.167151     -0.167151    -0.167151
# 900922                                 -0.169786     -0.169786    -0.169786
# 900964                                 -0.158754     -0.158754    -0.158754
# 900974                                 -0.132453     -0.132453    -0.132453
# 921923                                  1.350827     -0.251762     0.513889
#
#         BT549_BREAST  PC3_PROSTATE  OVCAR5_OVARY  LOXIMVI_SKIN  \
# 1          -0.231499     -0.403983     -0.593334     -0.193375
# 17          1.483613      1.302516     -0.422527      0.839155
# 89               NaN           NaN     -0.145313      0.228788
# 185              NaN           NaN     -0.853432      0.389991
# 295        -0.264586     -0.264586     -0.264586     -0.264586
# ...              ...           ...           ...           ...
# 900911     -0.167151     -0.167151     -0.167151           NaN
# 900922     -0.169786     -0.169786     -0.169786     -0.169786
# 900964     -0.158754     -0.158754     -0.158754     -0.158754
# 900974           NaN     -0.132453     -0.132453     -0.132453
# 921923     -0.604513     -0.268102     -1.152361      1.823544
#
#         HCT15_LARGE_INTESTINE  A549_LUNG  \
# 1                   -0.082824  -0.826223
# 17                  -0.630920  -0.941890
# 89                   0.236371  -0.433001
# 185                 -0.059621   0.500858
# 295                 -0.264586  -0.264586
# ...                       ...        ...
# 900911              -0.167151  -0.167151
# 900922              -0.169786        NaN
# 900964              -0.158754  -0.158754
# 900974              -0.132453  -0.132453
# 921923              -0.368297  -0.453344
#
#         MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 1                                       1.540716
# 17                                      1.686372
# 89                                      0.549935
# 185                                     1.675353
# 295                                    -0.264586
# ...                                          ...
# 900911                                 -0.167151
# 900922                                 -0.169786
# 900964                                 -0.158754
# 900974                                 -0.132453
# 921923                                  2.251157
#
# [24047 rows x 55 columns]

# %% [markdown]
# # Create train data table format

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = nci60Act[i].reset_index().dropna()
    tmp.columns = ['NSC', 'drug_response']
    tmp['cell_line'] = [i]*len(tmp)
    base = pd.concat([
        base,
        tmp
    ])
base = base.reset_index(drop=True)

# %%
len(set(base['NSC']))
# Out:
# 24047

# %% [markdown]
# # Read class label

# %%
class_nsc = pd.read_csv('../DrugCell/data_rcellminer/class_by_nsc.csv')
class_nsc.sort_values('NSC')
# Out:
#           NSC MECHANISM
# 112         1     Other
# 1200       17     Other
# 21579      89     Other
# 1355      185     Other
# 2118      295     Other
# ...       ...       ...
# 22699  900911     Other
# 22877  900922     Other
# 22701  900964     Other
# 21608  900974     Other
# 20537  921923     Other
#
# [23851 rows x 2 columns]

# %% [markdown]
# # Unique number of cell lines for each class
# There are 274 cell lines of DNA class

# %%
class_nsc.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other          22895
# Kinase           483
# DNA              274
# HDAC              46
# TUBB              45
# Apoptosis         38
# HSP90             16
# Ho                13
# Methylation       13
# PSM               13
# BRD               11
# Acetalax           4
# dtype: int64

# %% [markdown]
# # Merge label to main table on NSC

# %%
base_label = base.merge(class_nsc, on='NSC')
base_label
# Out:
#             NSC  drug_response                                 cell_line  \
# 0             1      -0.719253              SF295_CENTRAL_NERVOUS_SYSTEM
# 1             1      -0.390689                              SN12C_KIDNEY
# 2             1       2.110059                                HOP92_LUNG
# 3             1       1.914094                              NCIH522_LUNG
# 4             1      -0.357577              SF268_CENTRAL_NERVOUS_SYSTEM
# ...         ...            ...                                       ...
# 1209388  765429      -0.348806                              PC3_PROSTATE
# 1209389  765429      -0.952551                              OVCAR5_OVARY
# 1209390  765429      -0.048225                              LOXIMVI_SKIN
# 1209391  765429       0.410343                     HCT15_LARGE_INTESTINE
# 1209392  765429      -0.280316  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
#
#         MECHANISM
# 0           Other
# 1           Other
# 2           Other
# 3           Other
# 4           Other
# ...           ...
# 1209388     Other
# 1209389     Other
# 1209390     Other
# 1209391     Other
# 1209392     Other
#
# [1209393 rows x 4 columns]

# %% [markdown]
# # Merge SMILES to main table on NSC

# %%
smiles = pd.read_csv('../data/nsc_cid_smiles.csv')[['NSC', 'SMILES']]
base_smiles = base_label.merge(smiles, on='NSC').drop('NSC', axis=1)

# %%
base_smiles
# Out:
#          drug_response                                 cell_line MECHANISM  \
# 0            -0.719253              SF295_CENTRAL_NERVOUS_SYSTEM     Other
# 1            -0.390689                              SN12C_KIDNEY     Other
# 2             2.110059                                HOP92_LUNG     Other
# 3             1.914094                              NCIH522_LUNG     Other
# 4            -0.357577              SF268_CENTRAL_NERVOUS_SYSTEM     Other
# ...                ...                                       ...       ...
# 1177841      -0.348806                              PC3_PROSTATE     Other
# 1177842      -0.952551                              OVCAR5_OVARY     Other
# 1177843      -0.048225                              LOXIMVI_SKIN     Other
# 1177844       0.410343                     HCT15_LARGE_INTESTINE     Other
# 1177845      -0.280316  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Other
#
#                                                     SMILES
# 0                                        CC1=CC(=O)C=CC1=O
# 1                                        CC1=CC(=O)C=CC1=O
# 2                                        CC1=CC(=O)C=CC1=O
# 3                                        CC1=CC(=O)C=CC1=O
# 4                                        CC1=CC(=O)C=CC1=O
# ...                                                    ...
# 1177841  CC1=NC(C2=C(N1)C(=CC3=CC(=C(C(=C3)OC)OC)OC)CCC...
# 1177842  CC1=NC(C2=C(N1)C(=CC3=CC(=C(C(=C3)OC)OC)OC)CCC...
# 1177843  CC1=NC(C2=C(N1)C(=CC3=CC(=C(C(=C3)OC)OC)OC)CCC...
# 1177844  CC1=NC(C2=C(N1)C(=CC3=CC(=C(C(=C3)OC)OC)OC)CCC...
# 1177845  CC1=NC(C2=C(N1)C(=CC3=CC(=C(C(=C3)OC)OC)OC)CCC...
#
# [1177846 rows x 4 columns]

# %%
base_smiles.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other          1127388
# Kinase           25733
# DNA              14343
# TUBB              2365
# HDAC              2358
# Apoptosis         1912
# HSP90              869
# PSM                699
# Methylation        694
# Ho                 670
# BRD                597
# Acetalax           218
# dtype: int64

# %% [markdown]
# # Select DNA

# %%
df_dna = base_smiles[base_smiles['MECHANISM'] == 'DNA'].reset_index(drop=True)[['cell_line', 'SMILES', 'drug_response']]

# %% [markdown]
# # This has 14343 datapoints

# %%
df_dna.drop_duplicates()
# Out:
#                                       cell_line  \
# 0                  SF295_CENTRAL_NERVOUS_SYSTEM
# 1                                  SN12C_KIDNEY
# 2                                    HOP92_LUNG
# 3                                  NCIH522_LUNG
# 4                  SF268_CENTRAL_NERVOUS_SYSTEM
# ...                                         ...
# 14338                              OVCAR5_OVARY
# 14339                              LOXIMVI_SKIN
# 14340                     HCT15_LARGE_INTESTINE
# 14341                                 A549_LUNG
# 14342  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
#
#                                                   SMILES  drug_response
# 0      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.536910
# 1      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.602244
# 2      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -1.386098
# 3      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.013134
# 4      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.510978
# ...                                                  ...            ...
# 14338  CCCCCCCCCCCCCCCC(=O)NC1=NC(=O)N(C=C1)C2C(C(C(O...      -0.724381
# 14339  CCCCCCCCCCCCCCCC(=O)NC1=NC(=O)N(C=C1)C2C(C(C(O...       0.436674
# 14340  CCCCCCCCCCCCCCCC(=O)NC1=NC(=O)N(C=C1)C2C(C(C(O...      -0.717086
# 14341  CCCCCCCCCCCCCCCC(=O)NC1=NC(=O)N(C=C1)C2C(C(C(O...       0.353908
# 14342  CCCCCCCCCCCCCCCC(=O)NC1=NC(=O)N(C=C1)C2C(C(C(O...       3.898840
#
# [14343 rows x 3 columns]

# %% [markdown]
# # 55 cell lines and 244 drugs

# %%
len(set(df_dna['cell_line']))
# Out:
# 55

# %%
len(set(df_dna['SMILES']))
# Out:
# 244

# %%
pd.DataFrame(df_dna['cell_line'].value_counts())
# Out:
#                                              cell_line
# SF295_CENTRAL_NERVOUS_SYSTEM                       269
# OVCAR8_OVARY                                       269
# UACC257_SKIN                                       269
# UACC62_SKIN                                        269
# OVCAR4_OVARY                                       269
# KM12_LARGE_INTESTINE                               269
# NCIH460_LUNG                                       268
# A549_LUNG                                          268
# OVCAR5_OVARY                                       268
# SKMEL28_SKIN                                       268
# HCT116_LARGE_INTESTINE                             268
# NCIH23_LUNG                                        268
# HT29_LARGE_INTESTINE                               268
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           268
# U251MG_CENTRAL_NERVOUS_SYSTEM                      268
# HCT15_LARGE_INTESTINE                              267
# SF539_CENTRAL_NERVOUS_SYSTEM                       267
# COLO205_LARGE_INTESTINE                            267
# SW620_LARGE_INTESTINE                              267
# SNB75_CENTRAL_NERVOUS_SYSTEM                       267
# SF268_CENTRAL_NERVOUS_SYSTEM                       267
# SN12C_KIDNEY                                       267
# MALME3M_SKIN                                       266
# IGROV1_OVARY                                       266
# HOP62_LUNG                                         266
# NCIH322_LUNG                                       266
# CAKI1_KIDNEY                                       266
# NCIH226_LUNG                                       265
# NCIH522_LUNG                                       265
# LOXIMVI_SKIN                                       265
# RXF393_KIDNEY                                      265
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            264
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        264
# HCC2998_LARGE_INTESTINE                            264
# SKMEL5_SKIN                                        263
# SKOV3_OVARY                                        263
# EKVX_LUNG                                          263
# SKMEL2_SKIN                                        263
# A498_KIDNEY                                        262
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         261
# HOP92_LUNG                                         259
# M14_SKIN                                           257
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            256
# ACHN_KIDNEY                                        256
# TK10_KIDNEY                                        256
# 786O_KIDNEY                                        252
# MCF7_BREAST                                        250
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           244
# PC3_PROSTATE                                       240
# DU145_PROSTATE                                     239
# MDAMB435S_SKIN                                     239
# MDAMB231_BREAST                                    239
# HS578T_BREAST                                      238
# T47D_BREAST                                        235
# BT549_BREAST                                       231

# %%
pd.DataFrame(df_dna['SMILES'].value_counts())
# Out:
#                                                     SMILES
# COC1=CC(=CC(=C1O)OC)C2C3C(COC3=O)C(C4=CC5=C(C=C...     165
# CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C(...     163
# CC1=C(C(=O)C2=C(C1=O)N3CC4C(C3(C2COC(=O)N)OC)N4)N      110
# CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC(=O)NC2=CC=C(C...     110
# CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C(...     110
# ...                                                    ...
# CN(C)CCCN1C2=C3C(=C(C=C2)[N+](=O)[O-])NC4=C(C3=...      42
# C1CC(OC1CO)N2C=CC(=NC2=O)N                              42
# C1=CC=C(C(=C1)C(=O)NCCCC(C(=O)O)NC(=O)C2=CC=C(C...      41
# C1CCC2(CC1)C(=O)N(C(=O)N2)CCN(CCCl)CCCl                 40
# C1=CC=C(C(=C1)C(C2=CC=C(C=C2)Cl)C(Cl)Cl)Cl              39
#
# [244 rows x 1 columns]

# %%
indexes = list(df_dna.index)
rd.Random(42).shuffle(indexes)

# %%
test = indexes[round(len(indexes)*0.8):]
tmp = indexes[:round(len(indexes)*0.8)]
val = tmp[:len(test)]
train = tmp[len(test):]

# %%
train = df_dna.iloc[train]
test = df_dna.iloc[test]
val = df_dna.iloc[val]

# %%
print('train: ' + str(train.shape))
print('val: ' + str(val.shape))
print('test: ' + str(test.shape))
# Out:
# train: (8605, 3)
# val: (2869, 3)
# test: (2869, 3)

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train['cell_line'].value_counts()), 
        pd.DataFrame(val['cell_line'].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test['cell_line'].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
test.to_csv(
    '../DrugCell/data_rcellminer/test_DNA.txt', sep='\t', 
    header=None, index=None
)

val.to_csv(
    '../DrugCell/data_rcellminer/val_DNA.txt', sep='\t', 
    header=None, index=None
)

train.to_csv(
    '../DrugCell/data_rcellminer/train_DNA.txt', sep='\t', 
    header=None, index=None
)
