# %%
import pandas as pd
import numpy as np
import random as rd

from urllib.request import HTTPError
from tqdm import tqdm
from joblib import Parallel, delayed

# %% [markdown]
# # Read nci60byCell Line Table
#  Indexes are NSC and columns are Cell Lines' name

# %%
nci60Act = pd.read_csv("../data/nci60Act_ccle.csv", index_col=0)
cell2ind = list(pd.read_table("../DrugCell/data/cell2ind.txt", header=None)[1])
nci60Act = nci60Act[list(set(cell2ind) & set(nci60Act.columns))]
nci60Act
# Out:
#         DU145_PROSTATE  SKMEL5_SKIN  SF539_CENTRAL_NERVOUS_SYSTEM  \
# 1            -0.434885    -0.108730                     -0.380720
# 17           -0.941890    -0.941890                      1.140166
# 89                 NaN    -0.118614                     -0.165433
# 185                NaN     1.375379                      0.230402
# 295          -0.264586    -0.264586                     -0.264586
# ...                ...          ...                           ...
# 900911       -0.167151    -0.167151                     -0.167151
# 900922       -0.169786    -0.169786                     -0.169786
# 900964             NaN    -0.158754                     -0.158754
# 900974       -0.132453    -0.132453                     -0.132453
# 921923       -0.152586     1.026003                     -0.268661
#
#         TK10_KIDNEY  A498_KIDNEY  CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 1         -0.379420    -1.648059                                    1.642456
# 17        -0.761559    -0.329639                                    2.270240
# 89        -0.101929    -0.655707                                    0.061246
# 185       -0.904724          NaN                                    1.675353
# 295       -0.264586    -0.264586                                   -0.264586
# ...             ...          ...                                         ...
# 900911    -0.167151    -0.167151                                   -0.167151
# 900922    -0.169786    -0.169786                                   -0.169786
# 900964    -0.158754    -0.158754                                   -0.158754
# 900974    -0.132453    -0.132453                                   -0.132453
# 921923     1.538064    -0.920821                                    2.585790
#
#         SF268_CENTRAL_NERVOUS_SYSTEM  OVCAR4_OVARY  \
# 1                          -0.357577      2.081990
# 17                          0.335572      0.891796
# 89                         -0.184194      0.012308
# 185                         0.539343      0.487376
# 295                        -0.264586     -0.264586
# ...                              ...           ...
# 900911                     -0.167151     -0.167151
# 900922                     -0.169786     -0.169786
# 900964                     -0.158754     -0.158754
# 900974                     -0.132453     -0.132453
# 921923                     -0.126943     -0.229151
#
#         RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  \
# 1                                          1.504554
# 17                                         1.698491
# 89                                         1.191198
# 185                                       -0.024337
# 295                                             NaN
# ...                                             ...
# 900911                                     6.930661
# 900922                                    -0.169786
# 900964                                    -0.158754
# 900974                                    -0.132453
# 921923                                          NaN
#
#         U251MG_CENTRAL_NERVOUS_SYSTEM  ...  NCIH23_LUNG  M14_SKIN  \
# 1                           -0.266183  ...    -0.600872 -0.508668
# 17                          -0.843055  ...    -0.925414 -0.941890
# 89                          -0.093513  ...    -0.312738  0.430283
# 185                         -0.171509  ...     0.170420 -0.533247
# 295                         -0.264586  ...    -0.264586 -0.264586
# ...                               ...  ...          ...       ...
# 900911                            NaN  ...    -0.167151 -0.167151
# 900922                      -0.169786  ...    -0.169786 -0.169786
# 900964                      -0.158754  ...    -0.158754 -0.158754
# 900974                      -0.132453  ...    -0.132453 -0.132453
# 921923                       0.353673  ...    -0.030625 -0.388650
#
#         SKOV3_OVARY  HOP92_LUNG  PC3_PROSTATE  T47D_BREAST  \
# 1         -0.868240    2.110059     -0.403983     1.934731
# 17        -0.492953   -0.078754      1.302516     1.509397
# 89        -0.126557   -0.068839           NaN          NaN
# 185       -2.151708   -0.038789           NaN          NaN
# 295       -0.264586   -0.264586     -0.264586    -0.264586
# ...             ...         ...           ...          ...
# 900911    -0.167151         NaN     -0.167151    -0.167151
# 900922    -0.169786   -0.169786     -0.169786    -0.169786
# 900964    -0.158754   -0.158754     -0.158754    -0.158754
# 900974    -0.132453   -0.132453     -0.132453    -0.132453
# 921923    -1.092623   -0.238120     -0.268102          NaN
#
#         SF295_CENTRAL_NERVOUS_SYSTEM  ACHN_KIDNEY  UACC257_SKIN  \
# 1                          -0.719253     1.657273     -0.407149
# 17                          0.424922    -0.941890     -0.061915
# 89                         -1.429903    -0.144006     -0.070365
# 185                              NaN          NaN     -0.807890
# 295                        -0.264586    -0.264586     -0.264586
# ...                              ...          ...           ...
# 900911                     -0.167151    -0.167151     -0.167151
# 900922                     -0.169786    -0.169786     -0.169786
# 900964                     -0.158754    -0.158754     -0.158754
# 900974                     -0.132453    -0.132453     -0.132453
# 921923                     -0.961518    -0.140812     -0.240908
#
#         HCT15_LARGE_INTESTINE
# 1                   -0.082824
# 17                  -0.630920
# 89                   0.236371
# 185                 -0.059621
# 295                 -0.264586
# ...                       ...
# 900911              -0.167151
# 900922              -0.169786
# 900964              -0.158754
# 900974              -0.132453
# 921923              -0.368297
#
# [24047 rows x 55 columns]

# %% [markdown]
# # Create train data table format

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = nci60Act[i].reset_index().dropna()
    tmp.columns = ['NSC', 'drug_response']
    tmp['cell_line'] = [i]*len(tmp)
    base = pd.concat([
        base,
        tmp
    ])
base = base.reset_index(drop=True)

# %%
len(set(base['NSC']))
# Out:
# 24047

# %% [markdown]
# # Read class label

# %%
class_nsc = pd.read_csv('../DrugCell/data_rcellminer/class_by_nsc.csv')
class_nsc.sort_values('NSC')
# Out:
#           NSC MECHANISM
# 112         1     Other
# 1200       17     Other
# 21579      89     Other
# 1355      185     Other
# 2118      295     Other
# ...       ...       ...
# 22699  900911     Other
# 22877  900922     Other
# 22701  900964     Other
# 21608  900974     Other
# 20537  921923     Other
#
# [23851 rows x 2 columns]

# %% [markdown]
# # Unique number of cell lines for each class
# There are 274 cell lines of DNA class

# %%
class_nsc.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other          22895
# Kinase           483
# DNA              274
# HDAC              46
# TUBB              45
# Apoptosis         38
# HSP90             16
# Ho                13
# Methylation       13
# PSM               13
# BRD               11
# Acetalax           4
# dtype: int64

# %% [markdown]
# # Merge label to main table on NSC

# %%
base_label = base.merge(class_nsc, on='NSC')
base_label
# Out:
#             NSC  drug_response                     cell_line MECHANISM
# 0             1      -0.434885                DU145_PROSTATE     Other
# 1             1      -0.108730                   SKMEL5_SKIN     Other
# 2             1      -0.380720  SF539_CENTRAL_NERVOUS_SYSTEM     Other
# 3             1      -0.379420                   TK10_KIDNEY     Other
# 4             1      -1.648059                   A498_KIDNEY     Other
# ...         ...            ...                           ...       ...
# 1209388  631672      -0.671981                    HOP92_LUNG     Other
# 1209389  631672      -0.983003  SF295_CENTRAL_NERVOUS_SYSTEM     Other
# 1209390  631672      -0.272537                   ACHN_KIDNEY     Other
# 1209391  631672      -1.324494                  UACC257_SKIN     Other
# 1209392  631672       0.757200         HCT15_LARGE_INTESTINE     Other
#
# [1209393 rows x 4 columns]

# %% [markdown]
# # Merge SMILES to main table on NSC

# %%
smiles = pd.read_csv('../data/nsc_cid_smiles.csv')[['NSC', 'SMILES']]
base_smiles = base_label.merge(smiles, on='NSC').drop('NSC', axis=1)

# %%
base_smiles
# Out:
#          drug_response                     cell_line MECHANISM  \
# 0            -0.434885                DU145_PROSTATE     Other
# 1            -0.108730                   SKMEL5_SKIN     Other
# 2            -0.380720  SF539_CENTRAL_NERVOUS_SYSTEM     Other
# 3            -0.379420                   TK10_KIDNEY     Other
# 4            -1.648059                   A498_KIDNEY     Other
# ...                ...                           ...       ...
# 1177841      -0.671981                    HOP92_LUNG     Other
# 1177842      -0.983003  SF295_CENTRAL_NERVOUS_SYSTEM     Other
# 1177843      -0.272537                   ACHN_KIDNEY     Other
# 1177844      -1.324494                  UACC257_SKIN     Other
# 1177845       0.757200         HCT15_LARGE_INTESTINE     Other
#
#                                                     SMILES
# 0                                        CC1=CC(=O)C=CC1=O
# 1                                        CC1=CC(=O)C=CC1=O
# 2                                        CC1=CC(=O)C=CC1=O
# 3                                        CC1=CC(=O)C=CC1=O
# 4                                        CC1=CC(=O)C=CC1=O
# ...                                                    ...
# 1177841  CCC(=NNC(=O)C1=CC2=CC=CC=C2C=C1O)CC(=O)CCC(=O)...
# 1177842  CCC(=NNC(=O)C1=CC2=CC=CC=C2C=C1O)CC(=O)CCC(=O)...
# 1177843  CCC(=NNC(=O)C1=CC2=CC=CC=C2C=C1O)CC(=O)CCC(=O)...
# 1177844  CCC(=NNC(=O)C1=CC2=CC=CC=C2C=C1O)CC(=O)CCC(=O)...
# 1177845  CCC(=NNC(=O)C1=CC2=CC=CC=C2C=C1O)CC(=O)CCC(=O)...
#
# [1177846 rows x 4 columns]

# %%
base_smiles.value_counts('MECHANISM')
# Out:
# MECHANISM
# Other          1127388
# Kinase           25733
# DNA              14343
# TUBB              2365
# HDAC              2358
# Apoptosis         1912
# HSP90              869
# PSM                699
# Methylation        694
# Ho                 670
# BRD                597
# Acetalax           218
# dtype: int64

# %% [markdown]
# # Select DNA

# %%
df_dna = base_smiles[base_smiles['MECHANISM'] == 'DNA'].reset_index(drop=True)[['cell_line', 'SMILES', 'drug_response']]

# %% [markdown]
# # This has 14343 datapoints

# %%
df_dna.drop_duplicates()
# Out:
#                           cell_line  \
# 0                    DU145_PROSTATE
# 1                       SKMEL5_SKIN
# 2      SF539_CENTRAL_NERVOUS_SYSTEM
# 3                       TK10_KIDNEY
# 4                       A498_KIDNEY
# ...                             ...
# 14338                  PC3_PROSTATE
# 14339  SF295_CENTRAL_NERVOUS_SYSTEM
# 14340                   ACHN_KIDNEY
# 14341                  UACC257_SKIN
# 14342         HCT15_LARGE_INTESTINE
#
#                                                   SMILES  drug_response
# 0      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.507493
# 1      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.319437
# 2      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...       0.589970
# 3      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -1.641942
# 4      CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      -0.891882
# ...                                                  ...            ...
# 14338   CC(C(=O)O)OC1=CC=C(C=C1)OC2=CN=C3C=CC(=CC3=N2)Cl      -0.420205
# 14339   CC(C(=O)O)OC1=CC=C(C=C1)OC2=CN=C3C=CC(=CC3=N2)Cl      -0.420205
# 14340   CC(C(=O)O)OC1=CC=C(C=C1)OC2=CN=C3C=CC(=CC3=N2)Cl       0.091027
# 14341   CC(C(=O)O)OC1=CC=C(C=C1)OC2=CN=C3C=CC(=CC3=N2)Cl      -0.420205
# 14342   CC(C(=O)O)OC1=CC=C(C=C1)OC2=CN=C3C=CC(=CC3=N2)Cl      -0.420205
#
# [14343 rows x 3 columns]

# %% [markdown]
# # 55 cell lines and 244 drugs

# %%
len(set(df_dna['cell_line']))
# Out:
# 55

# %%
len(set(df_dna['SMILES']))
# Out:
# 244

# %%
pd.DataFrame(df_dna['cell_line'].value_counts())
# Out:
#                                              cell_line
# UACC62_SKIN                                        269
# KM12_LARGE_INTESTINE                               269
# UACC257_SKIN                                       269
# SF295_CENTRAL_NERVOUS_SYSTEM                       269
# OVCAR4_OVARY                                       269
# OVCAR8_OVARY                                       269
# OVCAR5_OVARY                                       268
# HT29_LARGE_INTESTINE                               268
# A549_LUNG                                          268
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           268
# U251MG_CENTRAL_NERVOUS_SYSTEM                      268
# HCT116_LARGE_INTESTINE                             268
# SKMEL28_SKIN                                       268
# NCIH23_LUNG                                        268
# NCIH460_LUNG                                       268
# SW620_LARGE_INTESTINE                              267
# COLO205_LARGE_INTESTINE                            267
# SNB75_CENTRAL_NERVOUS_SYSTEM                       267
# HCT15_LARGE_INTESTINE                              267
# SF539_CENTRAL_NERVOUS_SYSTEM                       267
# SF268_CENTRAL_NERVOUS_SYSTEM                       267
# SN12C_KIDNEY                                       267
# HOP62_LUNG                                         266
# CAKI1_KIDNEY                                       266
# IGROV1_OVARY                                       266
# NCIH322_LUNG                                       266
# MALME3M_SKIN                                       266
# LOXIMVI_SKIN                                       265
# NCIH226_LUNG                                       265
# RXF393_KIDNEY                                      265
# NCIH522_LUNG                                       265
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            264
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        264
# HCC2998_LARGE_INTESTINE                            264
# SKOV3_OVARY                                        263
# SKMEL5_SKIN                                        263
# SKMEL2_SKIN                                        263
# EKVX_LUNG                                          263
# A498_KIDNEY                                        262
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         261
# HOP92_LUNG                                         259
# M14_SKIN                                           257
# TK10_KIDNEY                                        256
# ACHN_KIDNEY                                        256
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            256
# 786O_KIDNEY                                        252
# MCF7_BREAST                                        250
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           244
# PC3_PROSTATE                                       240
# MDAMB231_BREAST                                    239
# MDAMB435S_SKIN                                     239
# DU145_PROSTATE                                     239
# HS578T_BREAST                                      238
# T47D_BREAST                                        235
# BT549_BREAST                                       231

# %%
pd.DataFrame(df_dna['SMILES'].value_counts())
# Out:
#                                                     SMILES
# COC1=CC(=CC(=C1O)OC)C2C3C(COC3=O)C(C4=CC5=C(C=C...     165
# CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C(...     163
# CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C(...     110
# CC1=C(C(=O)C2=C(C1=O)N3CC4C(C3(C2COC(=O)N)OC)N4)N      110
# C1=CN2C3C(C(C(O3)CO)O)OC2=NC1=N.Cl                     110
# ...                                                    ...
# CN(C)CCCN1C2=C3C(=C(C=C2)[N+](=O)[O-])NC4=C(C3=...      42
# C1CC(OC1CO)N2C=CC(=NC2=O)N                              42
# C1=CC=C(C(=C1)C(=O)NCCCC(C(=O)O)NC(=O)C2=CC=C(C...      41
# C1CCC2(CC1)C(=O)N(C(=O)N2)CCN(CCCl)CCCl                 40
# C1=CC=C(C(=C1)C(C2=CC=C(C=C2)Cl)C(Cl)Cl)Cl              39
#
# [244 rows x 1 columns]

# %%
pubchem_id =  pd.read_csv('../data/nsc_cid_smiles.csv')
# pubchem_id = {pubchem_id['CID'][i]:pubchem_id['SMILES'][i] for i in pubchem_id.index}

# %%
pubchem_id[24360]
# Out:
# 'CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3=C2)O'

# %%
df_dna[df_dna['SMILES'] == pubchem_id[24360]]
# Out:
#                          cell_line  \
# 1694                DU145_PROSTATE
# 1695                   SKMEL5_SKIN
# 1696  SF539_CENTRAL_NERVOUS_SYSTEM
# 1697                   TK10_KIDNEY
# 1698                   A498_KIDNEY
# ...                            ...
# 5184                   T47D_BREAST
# 5185  SF295_CENTRAL_NERVOUS_SYSTEM
# 5186                   ACHN_KIDNEY
# 5187                  UACC257_SKIN
# 5188         HCT15_LARGE_INTESTINE
#
#                                                  SMILES  drug_response
# 1694  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...       0.928772
# 1695  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...       0.264117
# 1696  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...       0.762820
# 1697  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...      -2.020112
# 1698  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...       0.087184
# ...                                                 ...            ...
# 5184  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...       0.667738
# 5185  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...       1.206083
# 5186  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...      -0.149960
# 5187  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...      -0.853218
# 5188  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...      -0.579374
#
# [110 rows x 3 columns]

# %%
pubchem_id[pubchem_id['SMILES'] == 'CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3=C2)O']
# Out:
#          NSC    CID                                             SMILES
# 1641   94600  24360  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# 3386  302991   2538  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...

# %%
indexes = list(df_dna.index)
rd.Random(42).shuffle(indexes)

# %%
test = indexes[round(len(indexes)*0.8):]
tmp = indexes[:round(len(indexes)*0.8)]
val = tmp[:len(test)]
train = tmp[len(test):]

# %%
train = df_dna.iloc[train]
test = df_dna.iloc[test]
val = df_dna.iloc[val]

# %%
print('train: ' + str(train.shape))
print('val: ' + str(val.shape))
print('test: ' + str(test.shape))
# Out:
# train: (8605, 3)
# val: (2869, 3)
# test: (2869, 3)

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train['cell_line'].value_counts()), 
        pd.DataFrame(val['cell_line'].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test['cell_line'].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
test.to_csv(
    '../DrugCell/data_rcellminer/test_DNA.txt', sep='\t', 
    header=None, index=None
)

val.to_csv(
    '../DrugCell/data_rcellminer/val_DNA.txt', sep='\t', 
    header=None, index=None
)

train.to_csv(
    '../DrugCell/data_rcellminer/train_DNA.txt', sep='\t', 
    header=None, index=None
)
