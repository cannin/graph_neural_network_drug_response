# %%
import pandas as pd
import numpy as np
import random as rd

from tqdm import tqdm
from joblib import Parallel, delayed

# %%
# Create PubChem_id list
pubchem_id = pd.read_csv('../DrugCell/data_rcellminer/pubchem_id_by_nsc.csv', index_col=0).dropna()
pubchem_id
# Out:
#          PUBCHEM_ID
# 17         219123.0
# 295          4775.0
# 353      24180741.0
# 384      54599265.0
# 534      16685698.0
# ...             ...
# 760087      60780.0
# 760091    9941647.0
# 760423    9955951.0
# 761431   42611257.0
# 781406  127025628.0
#
# [16522 rows x 1 columns]

# %%
#  Get smiles from PubChem ID  https://pubchem.ncbi.nlm.nih.gov/idexchange/idexchange.cgi
smiles = pd.read_table('../DrugCell/data_rcellminer/smiles_from_PubchemID.txt', header=None)
smiles.index = pubchem_id.index
smiles = smiles.drop(0, axis=1)
smiles.columns = ['smiles']
smiles = smiles.to_dict()['smiles']

# %%
nci60Act = pd.read_csv('../data/nci60Act_ccle.csv', index_col=0)
cell2ind = list(pd.read_table('../DrugCell/data/cell2ind.txt', header=None)[1])
nci60Act = nci60Act[list(set(cell2ind) & set(nci60Act.columns))]

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = nci60Act[i].reset_index().dropna()
    tmp.columns = ['nsc', 'drug_response']
    tmp['cell_line'] = [i]*len(tmp)
    base = pd.concat([
        base,
        tmp
    ])

# %%
class_nsc = pd.read_csv(
    '../DrugCell/data_rcellminer/class_by_nsc.csv',
)

# %%
class_nsc['MECHANISM'].value_counts()
# Out:
# Other          22895
# Kinase           483
# DNA              274
# HDAC              46
# TUBB              45
# Apoptosis         38
# HSP90             16
# Methylation       13
# Ho                13
# PSM               13
# BRD               11
# Acetalax           4
# Name: MECHANISM, dtype: int64

# %%
nsc_list = set(class_nsc['NSC'])
class_nsc = {class_nsc['NSC'][i] : class_nsc['MECHANISM'][i] for i in class_nsc.index}

# %%
base['label'] = [class_nsc[i] if i in nsc_list else None for i in base['nsc']]
base = base[base['label'] != 'Other'] \
    .reset_index(drop=True) \
    .drop('label', axis=1)
base['smiles'] = [smiles[i] if i in smiles.keys() else None for i in base.nsc]
base = base.dropna()
base = base.reset_index(drop=True)
base = base[['cell_line', 'smiles', 'drug_response']]

# %%
base
# Out:
#           cell_line                                             smiles  \
# 0       ACHN_KIDNEY  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 1       ACHN_KIDNEY                                    C1(=NC(=NN1)N)N
# 2       ACHN_KIDNEY  CC1C(C(C(C(O1)O[C@H]2CC[C@@]3([C@H]4CC[C@@]5([...
# 3       ACHN_KIDNEY                     C1CN1C2=NC(=NC(=N2)N3CC3)N4CC4
# 4       ACHN_KIDNEY  CCC(=O)O[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3[C@H]2CC...
# ...             ...                                                ...
# 16377  OVCAR4_OVARY  C[C@@H]1[C@H]([C@H](C[C@@H](O1)O[C@H]2CC[C@]3(...
# 16378  OVCAR4_OVARY  CC1=C2[C@H](C(=O)[C@@]3([C@H](C[C@@H]4[C@](C3[...
# 16379  OVCAR4_OVARY  C1=NC2=C(N=C(N=C2N1C3[C@H]([C@@H]([C@H](O3)CO)...
# 16380  OVCAR4_OVARY  CCC1=CC2C[C@@](C3=C(CN(C2)C1)C4=CC=CC=C4N3)(C5...
# 16381  OVCAR4_OVARY  CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=C2C...
#
#        drug_response
# 0           0.499337
# 1           2.032494
# 2           0.646581
# 3           1.548396
# 4          -0.200601
# ...              ...
# 16377       0.030270
# 16378      -2.319736
# 16379      -1.794858
# 16380       0.221991
# 16381      -0.616325
#
# [16382 rows x 3 columns]

# %%
len(set(base['cell_line']))
# Out:
# 55

# %%
len(set(base['smiles']))
# Out:
# 309

# %%
pd.DataFrame(base['cell_line'].value_counts())
# Out:
#                                              cell_line
# SF268_CENTRAL_NERVOUS_SYSTEM                       309
# NCIH460_LUNG                                       309
# OVCAR8_OVARY                                       308
# A549_LUNG                                          308
# SF295_CENTRAL_NERVOUS_SYSTEM                       308
# HCT116_LARGE_INTESTINE                             308
# HCT15_LARGE_INTESTINE                              307
# KM12_LARGE_INTESTINE                               306
# NCIH23_LUNG                                        306
# SW620_LARGE_INTESTINE                              305
# SF539_CENTRAL_NERVOUS_SYSTEM                       305
# SN12C_KIDNEY                                       305
# SKMEL5_SKIN                                        305
# OVCAR5_OVARY                                       304
# COLO205_LARGE_INTESTINE                            304
# LOXIMVI_SKIN                                       304
# U251MG_CENTRAL_NERVOUS_SYSTEM                      304
# ACHN_KIDNEY                                        302
# EKVX_LUNG                                          302
# HOP62_LUNG                                         302
# CAKI1_KIDNEY                                       302
# TK10_KIDNEY                                        302
# IGROV1_OVARY                                       302
# HT29_LARGE_INTESTINE                               301
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        301
# UACC257_SKIN                                       300
# M14_SKIN                                           300
# NCIH322_LUNG                                       299
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           299
# SKMEL28_SKIN                                       299
# 786O_KIDNEY                                        299
# UACC62_SKIN                                        299
# SKMEL2_SKIN                                        298
# NCIH522_LUNG                                       298
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            298
# RXF393_KIDNEY                                      296
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            295
# SKOV3_OVARY                                        295
# NCIH226_LUNG                                       294
# A498_KIDNEY                                        294
# HCC2998_LARGE_INTESTINE                            293
# OVCAR4_OVARY                                       293
# SNB75_CENTRAL_NERVOUS_SYSTEM                       293
# HOP92_LUNG                                         292
# MDAMB435S_SKIN                                     291
# PC3_PROSTATE                                       291
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         291
# DU145_PROSTATE                                     290
# MDAMB231_BREAST                                    288
# MALME3M_SKIN                                       287
# HS578T_BREAST                                      287
# MCF7_BREAST                                        286
# T47D_BREAST                                        275
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE           272
# BT549_BREAST                                       271

# %%
pd.DataFrame(base['smiles'].value_counts())
# Out:
#                                                     smiles
# CC(C)[NH-].CC(C)[NH-].O.O.Cl[Pt+2]Cl                    55
# CC1=C(C(=O)C2=C(C1=O)N3CC4[C@H]([C@]3([C@H]2COC...      55
# CC1=C(C(=O)C2=C(C1=O)N3CC4C(C3(C2COC(=O)NCCO)OC...      55
# CC[C@@]1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C...      55
# C[C@]12[C@H]([C@H](C[C@H](O1)N3C4=CC=CC=C4C5=C6...      55
# ...                                                    ...
# CC(=O)OC1CC2(C(CCC3(C2(CCC3C4=COC(=O)C=C4)O)C)C...      43
# CC(=O)O[C@@H]1C[C@]2([C@@H](CCC2=O)C3=C1[C@]4([...      42
# CN(CC1=CC=CC=C1)CC(=C)C2=CC=C(C=C2)C(=O)NC3=CC=...      42
# C1CCC2(CC1)C(=O)N(C(=O)N2)CCN(CCCl)CCCl                 40
# C[C@]12CC[C@@H](CC1=CC[C@@H]3[C@@H]2CC[C@]4([C@...      38
#
# [309 rows x 1 columns]

# %%
indexes = list(base.index)
rd.Random(42).shuffle(indexes)

# %%
test = indexes[round(len(indexes)*0.8):]
tmp = indexes[:round(len(indexes)*0.8)]
val = tmp[:len(test)]
train = tmp[len(test):]

# %%
train = base.iloc[train]
test = base.iloc[test]
val = base.iloc[val]

# %%
print('train: ' + str(train.shape))
print('val: ' + str(val.shape))
print('test: ' + str(test.shape))
# Out:
# train: (9830, 3)
# val: (3276, 3)
# test: (3276, 3)

# %%
df = pd.merge(
    pd.merge(
        pd.DataFrame(train['cell_line'].value_counts()), 
        pd.DataFrame(val['cell_line'].value_counts()), 
        left_index=True, right_index=True
    ), pd.DataFrame(test['cell_line'].value_counts()), 
    left_index=True, right_index=True
)
df.columns = ['train', 'val', 'test']
df.loc['total'] = np.sum(df, axis=0)

# %%
df
# Out:
#                                              train   val  test
# HT29_LARGE_INTESTINE                           198    57    46
# ACHN_KIDNEY                                    195    65    42
# U251MG_CENTRAL_NERVOUS_SYSTEM                  194    52    58
# SKMEL5_SKIN                                    193    58    54
# SN12C_KIDNEY                                   190    63    52
# A549_LUNG                                      189    59    60
# HOP62_LUNG                                     188    52    62
# SF295_CENTRAL_NERVOUS_SYSTEM                   187    60    61
# SKMEL28_SKIN                                   187    64    48
# UACC62_SKIN                                    186    43    70
# NCIH522_LUNG                                   186    51    61
# NCIH23_LUNG                                    186    68    52
# CAKI1_KIDNEY                                   184    56    62
# LOXIMVI_SKIN                                   184    53    67
# KM12_LARGE_INTESTINE                           183    58    65
# SW620_LARGE_INTESTINE                          182    62    61
# SF539_CENTRAL_NERVOUS_SYSTEM                   182    72    51
# NCIH322_LUNG                                   182    65    52
# HCC2998_LARGE_INTESTINE                        182    58    53
# IGROV1_OVARY                                   182    59    61
# K562_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        182    47    66
# HS578T_BREAST                                  181    45    61
# BT549_BREAST                                   181    44    46
# TK10_KIDNEY                                    181    56    65
# NCIH460_LUNG                                   180    70    59
# A498_KIDNEY                                    180    58    56
# UACC257_SKIN                                   180    60    60
# MDAMB435S_SKIN                                 179    47    65
# SKOV3_OVARY                                    179    60    56
# SF268_CENTRAL_NERVOUS_SYSTEM                   178    62    69
# COLO205_LARGE_INTESTINE                        178    60    66
# PC3_PROSTATE                                   177    55    59
# DU145_PROSTATE                                 177    60    53
# MDAMB231_BREAST                                177    50    61
# HCT116_LARGE_INTESTINE                         176    66    66
# HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        175    53    70
# OVCAR5_OVARY                                   175    66    63
# HCT15_LARGE_INTESTINE                          175    70    62
# SNB75_CENTRAL_NERVOUS_SYSTEM                   174    59    60
# MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       173    66    60
# CCRFCEM_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     173    53    65
# NCIH226_LUNG                                   172    69    53
# OVCAR8_OVARY                                   171    61    76
# MCF7_BREAST                                    171    57    58
# 786O_KIDNEY                                    170    75    54
# RPMI8226_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    170    68    63
# MALME3M_SKIN                                   170    57    60
# M14_SKIN                                       169    74    57
# RXF393_KIDNEY                                  169    64    63
# T47D_BREAST                                    169    63    43
# OVCAR4_OVARY                                   168    67    58
# SKMEL2_SKIN                                    167    59    72
# EKVX_LUNG                                      166    63    73
# HOP92_LUNG                                     165    60    67
# SR786_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       162    57    53
# total                                         9830  3276  3276

# %%
test.to_csv(
    '../DrugCell/data_rcellminer/test_rcell_wo_other.txt', sep='\t', 
    header=None, index=None
)

val.to_csv(
    '../DrugCell/data_rcellminer/val_rcell_wo_other.txt', sep='\t', 
    header=None, index=None
)

train.to_csv(
    '../DrugCell/data_rcellminer/train_rcell_wo_other.txt', sep='\t', 
    header=None, index=None
)
