# %%
import pandas as pd
import numpy as np

# %%
drugAnnot = pd.read_csv('data/smiles_by_nsc.csv', index_col=0).dropna()
drugAnnot.head()
# Out:
#                                                 SMILES
# 1                                    CC1=CC(=O)C=CC1=O
# 17                         CCCCCCCCCCCCCCCc1cc(O)ccc1N
# 89                                CN(C)CCC(=O)c1ccccc1
# 185  C[C@H]1C[C@H](C)C(=O)[C@@H](C1)[C@H](O)CC2CC(=...
# 295                                  OC(=O)CCCc1ccccc1

# %%
nci60Act = pd.read_csv('data/nci60Act.csv', index_col=0)
nci60Act.head()
# Out:
#       BR:MCF7  BR:MDA-MB-231  BR:HS 578T  BR:BT-549  BR:T-47D  CNS:SF-268  \
# 1   -0.271314      -0.303539   -0.815183  -0.231499  1.934731   -0.357577
# 17  -0.354110      -0.304675   -0.222024   1.483613  1.509397    0.335572
# 89        NaN            NaN         NaN        NaN       NaN   -0.184194
# 185       NaN            NaN         NaN        NaN       NaN    0.539343
# 295 -0.264586      -0.264586   -0.264586  -0.264586 -0.264586   -0.264586
#
#      CNS:SF-295  CNS:SF-539  CNS:SNB-19  CNS:SNB-75  ...   PR:PC-3  PR:DU-145  \
# 1     -0.719253   -0.380720   -1.281589   -0.175915  ... -0.403983  -0.434885
# 17     0.424922    1.140166   -0.941890    0.330808  ...  1.302516  -0.941890
# 89    -1.429903   -0.165433   -1.429903   -0.216723  ...       NaN        NaN
# 185         NaN    0.230402   -0.765829   -1.125208  ...       NaN        NaN
# 295   -0.264586   -0.264586   -0.264586   -0.264586  ... -0.264586  -0.264586
#
# ...

# %%
base = pd.DataFrame()
for i in nci60Act.columns:
    tmp = pd.DataFrame((nci60Act[i].dropna()))
    tmp.columns = ['Score']
    tmp['Cell Line'] = [i]*len(tmp)
    tmp = pd.merge(tmp, drugAnnot, left_index=True, right_index=True)
    base = pd.concat([base, tmp])
    
base = base[['Cell Line', 'SMILES', 'Score']]
base = base.reset_index(drop=True)

# %%
sanger_cell_lines = pd.read_table('data/sanger_cell_lines.txt').dropna()
