# %% [markdown]
# <a href="https://colab.research.google.com/github/cannin/graph_neural_network_drug_response/blob/6-drugcell-test/notebook/retraining_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Jun 24 19:16:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Clone the entire repo.
# !git clone https://github.com/inoue0426/DrugCell.git
# !ls
# Out:
# Cloning into 'DrugCell'...
# remote: Enumerating objects: 330, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 330 (delta 24), reused 34 (delta 10), pack-reused 282
# Receiving objects: 100% (330/330), 88.49 MiB | 26.38 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# DrugCell  sample_data

# %%
# %%time
# !rm -rf MODEL && mkdir MODEL

# !python -u ./DrugCell/code/train_drugcell.py \
                            -onto ./DrugCell/data/drugcell_ont.txt \
                            -gene2id ./DrugCell/data/gene2ind.txt \
                            -cell2id ./DrugCell/data/cell2ind.txt \
                            -drug2id ./DrugCell/data/drug2ind.txt \
                            -genotype ./DrugCell/data/cell2mutation.txt \
                            -fingerprint ./DrugCell/data/drug2fingerprint.txt \
                            -train ./DrugCell/data/train.txt \
                            -test ./DrugCell/data/val.txt \
                            -model ./MODEL \
                            -genotype_hiddens 6 \
                            -drug_hiddens "100,50,6" \
                            -final_hiddens 6 \
                            -epoch 100 \
                            -batchsize 100
                            #  \
                            # -cuda 0
# Out:
# Total number of cell lines = 1225
# Total number of drugs = 684
# There are 3008 genes
# There are 1 roots: GO:0008150
# There are 2086 terms
# There are 1 connected componenets
# term	GO:0007005	term_size	72	num_hiddens	6
# term	GO:0007006	term_size	32	num_hiddens	6
# term	GO:0008637	term_size	21	num_hiddens	6
# term	GO:0006281	term_size	99	num_hiddens	6
# term	GO:0006284	term_size	19	num_hiddens	6
# term	GO:0006283	term_size	13	num_hiddens	6
# term	GO:0019985	term_size	10	num_hiddens	6
# term	GO:0000724	term_size	15	num_hiddens	6
# term	GO:0006303	term_size	16	num_hiddens	6
# term	GO:0051052	term_size	119	num_hiddens	6
# term	GO:0044030	term_size	12	num_hiddens	6
# term	GO:0051054	term_size	80	num_hiddens	6
# term	GO:0010569	term_size	10	num_hiddens	6
# term	GO:0045830	term_size	12	num_hiddens	6
# term	GO:0045739	term_size	17	num_hiddens	6
# term	GO:2000279	term_size	13	num_hiddens	6
# term	GO:0032212	term_size	18	num_hiddens	6
# term	GO:0051973	term_size	18	num_hiddens	6
# ...

# %%
# !ls MODEL/
# Out:
# model_0.pt   model_25.pt  model_40.pt  model_56.pt  model_71.pt  model_87.pt
# model_10.pt  model_26.pt  model_41.pt  model_57.pt  model_72.pt  model_88.pt
# model_11.pt  model_27.pt  model_42.pt  model_58.pt  model_73.pt  model_89.pt
# model_12.pt  model_28.pt  model_43.pt  model_59.pt  model_74.pt  model_8.pt
# model_13.pt  model_29.pt  model_44.pt  model_5.pt   model_75.pt  model_90.pt
# model_14.pt  model_2.pt   model_45.pt  model_60.pt  model_76.pt  model_91.pt
# model_15.pt  model_30.pt  model_46.pt  model_61.pt  model_77.pt  model_92.pt
# model_16.pt  model_31.pt  model_47.pt  model_62.pt  model_78.pt  model_93.pt
# model_17.pt  model_32.pt  model_48.pt  model_63.pt  model_79.pt  model_94.pt
# model_18.pt  model_33.pt  model_49.pt  model_64.pt  model_7.pt	 model_95.pt
# model_19.pt  model_34.pt  model_4.pt   model_65.pt  model_80.pt  model_96.pt
# model_1.pt   model_35.pt  model_50.pt  model_66.pt  model_81.pt  model_97.pt
# ...

# %%
from google.colab import files

files.download('./MODEL/model_40.pt')
