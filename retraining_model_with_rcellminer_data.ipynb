# %% [markdown]
# <a href="https://colab.research.google.com/github/cannin/graph_neural_network_drug_response/blob/6-drugcell-test/retraining_model_with_rcellminer_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the entire repo.
# !git clone https://github.com/inoue0426/DrugCell.git
# !ls
# Out:
# Cloning into 'DrugCell'...
# remote: Enumerating objects: 352, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 352 (delta 36), reused 69 (delta 36), pack-reused 282
# Receiving objects: 100% (352/352), 228.61 MiB | 35.33 MiB/s, done.
# Resolving deltas: 100% (177/177), done.
# Checking out files: 100% (52/52), done.
# DrugCell  sample_data

# %%
# %%time
# !rm -rf MODEL && mkdir MODEL

# !python -u ./DrugCell/code/train_drugcell.py \
                            -onto ./DrugCell/data/drugcell_ont.txt \
                            -gene2id ./DrugCell/data/gene2ind.txt \
                            -cell2id ./DrugCell/data/cell2ind.txt \
                            -drug2id ./DrugCell/data/drug2ind_rcell.txt \
                            -genotype ./DrugCell/data/cell2mutation.txt \
                            -fingerprint ./DrugCell/data/mfp.txt \
                            -train ./DrugCell/data/train_rcell.txt \
                            -test ./DrugCell/data/val_rcell.txt \
                            -model ./MODEL \
                            -genotype_hiddens 6 \
                            -drug_hiddens "512, 100,50,6" \
                            -final_hiddens 6 \
                            -epoch 300 \
                            -batchsize 5000
# Out:
# Total number of cell lines = 1225
# Total number of drugs = 16522
# There are 3008 genes
# There are 1 roots: GO:0008150
# There are 2086 terms
# There are 1 connected componenets
# term	GO:0007005	term_size	72	num_hiddens	6
# term	GO:0007006	term_size	32	num_hiddens	6
# term	GO:0008637	term_size	21	num_hiddens	6
# term	GO:0006281	term_size	99	num_hiddens	6
# term	GO:0006284	term_size	19	num_hiddens	6
# term	GO:0006283	term_size	13	num_hiddens	6
# term	GO:0019985	term_size	10	num_hiddens	6
# term	GO:0000724	term_size	15	num_hiddens	6
# term	GO:0006303	term_size	16	num_hiddens	6
# term	GO:0051052	term_size	119	num_hiddens	6
# term	GO:0044030	term_size	12	num_hiddens	6
# term	GO:0051054	term_size	80	num_hiddens	6
# term	GO:0010569	term_size	10	num_hiddens	6
# term	GO:0045830	term_size	12	num_hiddens	6
# term	GO:0045739	term_size	17	num_hiddens	6
# term	GO:2000279	term_size	13	num_hiddens	6
# term	GO:0032212	term_size	18	num_hiddens	6
# term	GO:0051973	term_size	18	num_hiddens	6
# ...

# %%
# !ls MODEL/
# Out:
# model_0.pt   model_16.pt  model_22.pt  model_29.pt  model_35.pt  model_4.pt
# model_10.pt  model_17.pt  model_23.pt  model_2.pt   model_36.pt  model_5.pt
# model_11.pt  model_18.pt  model_24.pt  model_30.pt  model_37.pt  model_6.pt
# model_12.pt  model_19.pt  model_25.pt  model_31.pt  model_38.pt  model_7.pt
# model_13.pt  model_1.pt   model_26.pt  model_32.pt  model_39.pt  model_8.pt
# model_14.pt  model_20.pt  model_27.pt  model_33.pt  model_3.pt	 model_9.pt
# model_15.pt  model_21.pt  model_28.pt  model_34.pt  model_40.pt

# %%
import IPython
display(IPython.display.Audio("Warning.mp3", autoplay=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-376e8bdfa05e> in <module>()
#       1 import IPython
# ----> 2 display(IPython.display.Audio("Warning.mp3", autoplay=True))
#
# /usr/local/lib/python3.7/dist-packages/IPython/lib/display.py in __init__(self, data, filename, url, embed, rate, autoplay)
#      97
#      98         if self.data is not None and not isinstance(self.data, bytes):
# ---> 99             self.data = self._make_wav(data,rate)
#     100
#     101     def reload(self):
#
# /usr/local/lib/python3.7/dist-packages/IPython/lib/display.py in _make_wav(self, data, rate)
#     121             import numpy as np
#     122
# --> 123             data = np.array(data, dtype=float)
#     124             if len(data.shape) == 1:
#     125                 nchan = 1
#
# ValueError: could not convert string to float: 'Warning.mp3'

# %%
from google.colab import files

files.download('./MODEL/model_0.pt')

# %%
ls
